# %% [markdown]
# 常微分方程第一次作业

# %% [markdown]
# ## 2015750414颜俊帆

# %% [markdown]
# 3.(7)$因为y=x^2+1$
#     $y'=2x,$
#     $所以y^2-(x^2+1)y+2x=y^2-y^2+2x=y',$
#     $因此y=x^2+1是方程y'=y^2-(x^2+1)y+2x的解$

# %% [markdown]
# (8)$因为y=-\frac{g(x)}{f(x)},所以y'=-\frac{g'(x)f(x)-f'(x)g(x)}{f(x)^2}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)},又\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}=\frac{f'(x)}{g(x)}(-\frac{g(x)}{f(x)})^2-\frac{g'(x)}{f(x)}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}=y'$
# $所以,y=-\frac{g(x)}{f(x)}是方程y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}的解$

# %% [markdown]
# $4.(1)由\frac{dy}{dx}=2x,得dy=2xdx,方程两边积分，即得y=x^2=c,其中c为任意常数，所以方程\frac{dy}{dx}=2x的通解为y=x^2+c,c为任意常数$

# %% [markdown]
# $(2)把点(1,4)代入y=x^2=c得c=3,所以过点(1,4)的特解为y=x^2+3$

# %% [markdown]
# $(3)因为与直线相切，所以方程组[y=x^2+c,y=2x+3]有且只有唯一一组解，即x^2=c=2x=3有唯一解，故c=4,因此与直线y=2x+3相切的解是y=x^2+4$

# %% [markdown]
# $(4)因为integrate(y,x,0,1)=integrate(x^2+c,x,0,1)=\frac{1}{3}+c=2,所以c=\frac{5}{3},因此满足条件integrate(y,x,0,1)的解为y=x^2+\frac{5}{3}$

# %%
var('x y')
y=x^2+3
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+4
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+5/3
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $1(6)原方程变形为xdy-ydx+\sqrt(x^2-y^2)dx=0$
# $当y^2 ≠ x^2时，两边同时除以\sqrt(x^2-y^2)得\frac{xdy-ydx}{\sqrt(x^2-y^2)}+dx=0$
# $即\frac{d(\frac{dy}{dx})}{\sqrt(1-(\frac{y}{x})^2)}+\frac{1}{x}dx=0$
# $两边积分得arcsin\frac{y}{x}+ln|x|=c,其中c为任意常数$
# $另外，当y^2=x^2时，易验证y^2=x^2也是方程的解$
# $所以原方程的解为y^2=x^2及arcsin\frac{y}{x}+ln|x|=c$

# %% [markdown]
# $(7)当tany ≠ 0时，即y ≠ kπ，k=0,±1,±2，…时分离变量得cotydy=tanxd$
# $两边同时积分，即得ln|siny|=-ln|cosx|+c1,其中c1为任意常数$
# $即sinycosx=c,其中c=±e^c1为非零常数$
# $另外，y=kπ，k=0,±1,±2，…也是方程的解$
# $所以，原方程的解为sinycosx=c及y=kπ，k=0,±1,±2，…$

# %% [markdown]
# $2(6)令u=y^2，则方程可变形为\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$
# $再令v=\frac{u}{x}即u=vx，则上面方程化为x\frac{dv}{dx}+v=\frac{3v^2-6}{2v+1}$
# $整理得7/5\frac{dv}{v-3}+3/5\frac{dv}{v+2}=\frac{dx}{x}$
# $两边同时积分得(v-3)^7(v=2)^3=cx^5,其中c为正常数$
# $代回原变量，并且化简原方程的解为(y^3-3x)^7(y^3+2x)^3=cx^15$

# %% [markdown]
# $(7)原方程可以变形为\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
# $令u=x^2-1,v=y^2+1,则方程可化为\frac{dv}{du}=\frac{2u+3v}{3u+2v}$
# $再令w=\frac{v}{u}即v=uw,则有\frac{dv}{du}=w+u\frac{dw}{du},从而u\frac{dw}{du}=\frac{2-2w^2}{3+2w}$
# $分离变量并化简得\frac{4}{u}du=(\frac{5}{1-w}+\frac{1}{1+w})dw$
# $两边积分得u^4(1-w)^5=c(1+w)$
# $代回原变量即得原方程的解为$
# $(x^2-y^2-2)^5=c(x^2+y^2),其中c为任意常数$

# %% [markdown]
# $因为y2(t)=y1(t-t0)$
# $所以y2(t+t0)=y1(t)$
# $又因为y1(t)是\frac{dy}{dt}=f(y),y(0)=y0的解$
# $所以y2(t+t0)是\frac{dy}{dt}=f(y),y(t0)=y0的解其中t0为任意常数$
# $所以y2(t)是\frac{dy}{dt}=f(y),y(t0)=y0的解$
# $即y2(t)=y1(t-t0)是\frac{dy}{dt}=f(y),y(t0)=y0的解$

# %% [markdown]
# # <font color='red'>A 12/9
