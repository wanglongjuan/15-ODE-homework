# %% [markdown]
# ## page 27
# $3.验证下列各函数是相应微分方程的解：$
#
# $(7)y=x^2+1,y'=y^2-(x^2+1)y+2x; $
#
# $解：∵y=x^2+1,∴y'=2x $
#
# $y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x=y'$
#
# $∴y=x^2+1是方程y'=y^2-(x^2+1)y+2x的解$
#
# $(8)y=-\frac{g(x)}{f(x)},y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}.$
#
# $解：∵y'=-\frac{g'(x)f(x)-g(x)f'(x)}{(f(x))^2}=\frac{g(x)f'(x)}{(f(x))^2}-\frac{g'(x)}{f(x)}$
#
# $\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}=\frac{g(x)f'(x)}{(f(x))^2}-\frac{g'(x)}{f(x)}=y'$
#
# $∴y=-\frac{g(x)}{f(x)}是方程y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}的解$
#
# $4.给定一阶微分方程\frac{\mathrm dy}{\mathrm dx}=2x.$
#
# $(1)求出它的通解；$
#
# $(2)求通过点（1,4）的特解；$
#
# $(3)求出与直线y=2x+3相切的解；$
#
# $(4)求出满足条件\int_0^1 \mathrm y \mathrm{d}x=2的解；$
#
# $(5)绘出（2），（3），（4）中的解的图形.$
#
# $解：（1）\frac{\mathrm dy}{\mathrm dx}=2x$
#
# $\mathrm dy=2x\mathrm dx$
#
# $∴通解是y=x^2+c,c为任意常数.$
#
# $（2）带入x=1,y=4,得c=3$
#
# $∴过点（1,4）的特解是y=x^2+3$
#
# $（3）∵与直线相切，∴两方程只有一个公共解$
#
# $x^2+c=2x+3$
#
# $∵4-4(c-3)=0,∴c=4$
#
# $即y=x^2+4$
#
# $（4）∵\int_0^1 \mathrm y \mathrm{d}x=\int_0^1 \mathrm (x^2+c) \mathrm{d}x=[x^3/3+cx]_0^1=1/3+c$
#
# $当c=\frac{5}{3}时，上式等于2$
#
# $即满足条件的解为y=x^2+\frac{5}{3}$

# %%
(5)
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## Page  42-43   $1.求下列方程的解$
#
# $(6)x\frac{\mathrm dy}{\mathrm dx}-y+\sqrt{x^2-y^2}=0$
#
# $解：x\mathrm dy-y\mathrm dx+\sqrt{x^2-y^2}dx=0$
#
# $当x^2=y^2时，是此方程的解$
#
# $当x^2\neq y^2时，两边同除以\sqrt{x^2-y^2}得$
#
# $\frac{xdy-ydx}{\sqrt{x^2-y^2}}+\mathrm dx=0$
#
# $\frac{\mathrm d(\frac{y}{x})}{\sqrt{1-(\frac{y}{x})^2}}+\frac{1}{x}\mathrm dx=0$
#
# $两边积分得\arcsin\frac{y}{x}+\ln|x|=c,c为任意常数$
#
# $∴原方程的解为x^2=y^2或\arcsin\frac{y}{x}+\ln|x|=c$
#
# $（7）\tan y \mathrm dx-\cot x \mathrm dy=0;$
#
# $当y\neq k\pi时,k取整数$
#
# $\cot y \mathrm dy=\tan x\mathrm dx$
#
# $同时积分得\ln|\sin y|=-\ln|\cos x|+c_1,c_1为任意常数$
#
# $即\sin y\cos x=c,c=3^{c_1}为任意常数$
#
# $当y=k\pi时（k取整数），此时也为方程的解$
#
# $∴\sin y \cos x=c或y=k\pi是原方程的解$
#
# $2.作适当的变量变换求解下列的方程：$
#
# $(6)\frac{\mathrm dy}{\mathrm dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2};$
#
# $令u=y^3,\frac{\mathrm du}{\mathrm dx}=\frac{\mathrm dy^3}{\mathrm dx}=\frac{3y^2\mathrm dy}{\mathrm dx}$
#
# $\frac{\mathrm du}{3y^2\mathrm dx}=\frac{\mathrm dy}{\mathrm dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$
#
# $∴\frac{\mathrm du}{\mathrm dx}=\frac{3y^6-6x^2}{2xy^3+x^2}=\frac{3u^2-6x^2}{2xu+x^2}$
#
# $再令v=\frac{u}{x},则x\frac{\mathrm dv}{\mathrm dx}+v=\frac{3v^2-6}{2v+1}$
#
# $\frac{7}{5}\frac{\mathrm dv}{v-3}+\frac{3}{5}\frac{\mathrm dv}{v+2}=\frac{\mathrm dx}{x}$
#
# $同时积分得(v-3)^7(v+2)^3=cx^5,c取正常数$
#
# $代入v=\frac{u}{x}=\frac{y^3}{x},化简得(y^3-3x)^7(y^3+2x)=cx^{15}$
#
# $(7)\frac{\mathrm dy}{\mathrm dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}$
#
# $解：\frac{y\mathrm dy}{x\mathrm dx}=\frac{2x^2+xy^2+1}{3x^2+2y^2-1}$
#
# $\frac{\mathrm dy^2}{\mathrm dx^2}=\frac{2y\mathrm dy}{2x\mathrm dx}=\frac{2x^2+xy^2+1}{3x^2+2y^2-1}$
#
# $令u=x^2-1,v=y^2+1,则\frac{\mathrm dv}{\mathrm du}=\frac{2u+3v}{3u+2v}$
#
# $再令\omega=\frac{v}{u},则u \frac{\mathrm d\omega}{\mathrm du}+\omega=\frac{2+3\omega}{3+2\omega}$
#
# $c(1+\omega)=u^4(1-\omega)^5,代入\omega=\frac{v}{u}，u=x^2-1,v=y^2+1$
#
# $得c(x^2+y^2)=(x^2-y^2-2)^5,c为任意常数$
#
# $补充题：已知y_1(t)是\frac{\mathrm dy}{\mathrm dt}=f(y),y(0)=y_0的解$
#
# $验证：y_2(t)=y_1(t-t_0)是\frac{\mathrm dy}{\mathrm dt}=f(y),y(t_0)=y_0的解$
#
# $解：∵\frac{y_2(t)}{\mathrm dt}=\frac{y_1(t-t_0)}{\mathrm dt}=\frac{y_1(t-t_0)}{\mathrm d(t-t_0)}=f(y_1(t-t_0))=f(y_2)$
#
# $∴y_2(t)=y_1(t-t_0)是\frac{\mathrm dy}{\mathrm dt}=f(y)的解$
#
# $当t-t_0=0时，y_1(t-t_0)=y_0=y_2(t_0)$
#
# $∴y_2(t)=y_1(t-t_0)是y(t_0)=y_0的解，即证$

# %% [markdown]
# # <font color='red'>A  12/9
