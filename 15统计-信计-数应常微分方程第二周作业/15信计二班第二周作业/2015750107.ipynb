# %% [markdown]
# **习题1.2**
#
# 3.验证下列各函数是相应微分方程的解：
#
# (7) $y=x^2+1,y'=y^2-(x^2+1）y+2x$
#
# (8) $y=\frac{-g(x)}{f(x)},y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$

# %% [markdown]
# 解：
#
# （7)
#
# $y=x^2+1,y'=2x$
#
# $左=2x$
#
# $右=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x;$
#
# $左=右$
#
# （8）
#
# $y'=\frac{g'(x)f(x)-g(x)f'(x)}{f^2(x)}$
#
# $y'=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}$
#
# $y'=\frac{f'(x)}{g(x)}(\frac{-g(x)}{f(x)})^2-\frac{g'(x)}{f(x)}$
#
# $y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$

# %% [markdown]
# 4.给定一阶微分方程$\frac{dy}{dx}=2x$,
#
# （1）求出它的通解；
#
# （2）求出通过点（1，4）的特解；
#
# （3）求出与直线$y=2x+3$相切的解；
#
# （4）求出满足条件\int^1_0{y}{dx}=2的特解；
#
# （5）绘出（2）、（3）、（4）中的解的图形。

# %% [markdown]
# 解：
#
# （1）
# $dy=2xdx$
#
# $y=x^2+c (c为任意常数)$
#
# （2）
#
# $4=1^2+c$
#
# $c=3$
#
# $y=x^2+3$
#
# (3)
#
# $
# \begin{cases}
# y=x^2+c\\
# y=2x+3
# \end{cases}$$$
#
# 由题意，该方程组有唯一解，得
#
# $c=4$
#
# $y=x^2+4$
#
# (4)
#
# $\int^1_0{y}{dx}=\int^1_0{x^2+c}{dx}=[\frac{x^2}{3}+cx]^1_0=\frac{1}{3}+c=2$
#
# $c=\frac{5}{3}$
#
# $y=x^2+\frac{5}{3}$

# %%
(5)
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
g(x)=x^2+4
plot(g(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
h(x)=x^2+5/3
plot(h(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# **习题2.1**
#
# 1.求下列方程的解：
#
# （6）$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}$
#
# （7）$\tan{y}dy-\cot{x}dx=0 $

# %% [markdown]
# 解：
#
# （6）
#
# $xdy-ydx+\sqrt{x^2-y^2}dx=0$
#
# 当$x^2$不等于$y^2$时，
#
# $\frac{xdy-ydx}{\sqrt{x^2-y^2}}+dx=0$
#
# $\frac{d(\frac{y}{x})}{\sqrt{1-(\frac{y}{x})^2}}+\frac{1}{x}dx=0$
#
# $\arcsin{\frac{y}{x}}+\ln{|x|}=c (c为任意常数)$
#
# 当$x^2=y^2$时，易证其同样为方程的解.
#
# （7）
#
# 当$\tan{y}$不等于0，即y不等于$k\pi$,k为任意整数
#
# $\cot{y}dy=\tan{x}dx$
#
# $\ln{\sin{y}}=-\ln{|\cos{x}|}+c'$
#
# $\sin{y}\cos{x}=c$
#
# 当$y=k\pi$ k为任意整数,易证其同样为方程的解.

# %% [markdown]
# 2.作适当的变量变换求解下列方程：
#
# （6）$\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^6+x^2y^2}$
#
# （7）$\frac{dy}{dx}=\frac{2x^3+3xy+x}{3x^2+2y^3-y}$

# %% [markdown]
# 解：
#
# （6）
#
# 令$u=y^3$,
#
# $\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$
#
# 再令$v=\frac{u}{x}$
#
# $x\frac{dv}{dx}+v=\frac{3v^2-6}{2v+1}$
#
# $\frac{7}{5}(\frac{dv}{v-3})+\frac{3}{5}(\frac{dv}{v+2})=\frac{dx}{x}$
#
# $(v-3)^7(v+2)^3=cx^5$
#
# $(y^3-3x)^7(y^3+2x)^3=cx^15$ c为任意整数
#
# （7）
#
# $\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# $\frac{dy^2}{dx^2}=2x^2+3y$
#
# 令$u=x^2-1,v=y^2+1$
#
# $\frac{dv}{du}+w=\frac{2+3w}{3+2w}$
#
# $c(1+w)=u^4(1-w)^5$
#
# $c(x^2+y^2)=y^2-x^2+2$ c为任意常数

# %% [markdown]
# 证明题：
#
# 已知：$y_1(t)$$是\frac{dy}{dt}=f(y),y(0)=y_0$的解
#
# 证明：$y_2(t)=y_1(t-t_0)$是$\frac{dy}{dt}=f(y),y(t_0)=y_0$的解

# %% [markdown]
# 证明：
#
# $\frac{dy_2(t)}{dt}=\frac{dy_1(t-t_0)}{d(t-t_0)}=f(y_1(t-t_0))=f(y_2(t))$
#
# 所以$y_2(t)=y_1(t-t_0)$是$\frac{dy}{dt}=f(y)$的解
#
# $y_2(t_0)=y_1(t_0-t_0)=y_1(0)=y_0$
#
# 所以$y_2(t)=y_1(t-t_0$是$y(t_0)=y_0$的解

# %% [markdown]
# # <font color='red'>A+  12/9
