# %% [markdown]
# # $$第一次作业$$

# %% [markdown]
# ## $ 3.验证下列个函数是相应微分的解$

# %% [markdown]
# ### $(7)·y=x^2+1, y`=y^2-(x^2+1)y+2x;$

# %%
var(x)
y=function('y')(x)
y=x^2+1
de=diff(y,x,1)==y^2-(x^2+1)*y+2*x
show(de)
# Out:
# 2*x == 2*x

# %% [markdown]
# ### $所以函数y=x^2+1是相应微分方程y`=y^2-(x^2+1)y+2x的解$

# %% [markdown]
# ### $(8).y=-g(x)/f(x), y`=f`(x)/g(x)*y^2-g`(x)/f(x);$

# %%
var('x')
f=function('f')(x)
g=function('g')(x)
y=-g/f
G=diff(g,x,1)
F=diff(f,x,1)
de=diff(y,x,1)==F/g*y^2-G/f
show(de)
# Out:
# g(x)*D[0](f)(x)/f(x)^2 - D[0](g)(x)/f(x) == g(x)*D[0](f)(x)/f(x)^2 - D[0](g)(x)/f(x)

# %% [markdown]
# ### $所以函数y=−g(x)/f(x)是微分方程y‘=f‘(x)/g(x)∗y2−g‘(x)/f(x)d的解$

# %% [markdown]
# ## $4.给定一阶微分方程dy/dx=2x,$

# %% [markdown]
# ### $(1).求出它的通解$

# %%
var('x')
y=function('y')(x)
de=diff(y,x,1)-2*x==0
show(de)
show(desolve(de,y))
# Out:
# -2*x + D[0](y)(x) == 0
# x^2 + _C

# %% [markdown]
# ### $(2).求通过点（1，4）的特解$

# %% [markdown]
# ### $解：$

# %% [markdown]
# ### $由（1）知他的特解为：y=x^2+c$

# %% [markdown]
# ### $当 x=1,y=4,时，c=3$

# %% [markdown]
# ### $所以它的一个特解为：y=x^2+3$

# %% [markdown]
# ## $（3）。求出与直线y=2*x+3相切的解$

# %% [markdown]
# ### $解：$

# %% [markdown]
# ### $仍由（1）知，方程的通解为y=x^2+c$

# %% [markdown]
# ### $两边求导得：y=2*x$
# ### $因为与y=2*x+3相切，所以x=1,则y=5$

# %% [markdown]
# ### $即切点为（1，5），代入通解得：c=4$
# ### $所以与直线y=2*x+3相切的解为y=x^2+4$

# %% [markdown]
# ### $(4)求出满足条件\int\limits_0^1y\,\mathrm{d}x=2的解$

# %% [markdown]
# ### $解：$
# ### $由条件\int\limits_0^1y\,\mathrm{d}x=2可知（\left.\frac{x^3}{3}+cx)\right|_0^1=\frac{\mathrm3}+c=2$
# ### $所以c=\frac{\mathrm5}{\mathrm3}$
# ### $所以满足条件\int\limits_0^1y\,\mathrm{d}x=2的解为y=x^2+\frac{\mathrm5}{\mathrm3}$

# %% [markdown]
# ## $(5).绘出（2），（3），（4）中解的图形$

# %%
p=plot(x^2+3,x,-1,1)
show(p)
s=plot(x^2+4,x,-1,1)
show(s)
j=plot(x^2+5/3,x,-1,1)
show(j)
# Out:
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## $1.求下列方程的解$
# ### $(6)  x\frac{\mathrm dy}{\mathrm dx}-y+\sqrt{x^2-y^2}=0$

# %% [markdown]
# ### $解：$
# ### $令\frac{\mathrm y}{\mathrm x}=u, y=ux, \frac{\mathrm dy}{\mathrm dx}=u+x\frac{\mathrm y}{\mathrm x},则原方程化为：$
# ### $\frac{\mathrm du}{\mathrm dx}=\frac{\mathrm {\sqrt{x^2（1-u^2)}}}{\mathrm x},分离变量得：\frac{\mathrm 1}{\mathrm {\sqrt(1-u^2)}}du=sgn x\frac{\mathrm 1}{\mathrm x}dx$       }

# %% [markdown]
# ### $ 两边积分得:\arcsin u=sgn xln|x|+c$
# ### $ 代回原来的变量，得\arcsin \frac{\mathrm y}{\mathrm x}=sgn xln|x|+c$
# ### $ 另外，y^2=x^2也是方程的解$

# %% [markdown]
# ## $(7).\tan ydx-\cot xdy=0$

# %% [markdown]
# ### $解：$
# ### $变量奋力得：ctgydy=tgxdx$
# ### $两边积分得：\ln|\sin y|=-\ln|\cos x|+c$

# %% [markdown]
# # <font color='red'>特解？？

# %% [markdown]
# ## $2.做适当变量变换求解下列方程$

# %% [markdown]
# ### $(6)\frac{\mathrm dy}{\mathrm dx}=\frac{\mathrm y^6-2x^2}{\mathrm 2xy^5+x^2y^2}$

# %% [markdown]
# ### $解：$
# ### $\frac{\mathrm dy}{\mathrm dx}=\frac{\mathrm (y^3)^2-2x^2}{\mathrm y^2(2xy^3+x^2)}=\frac{\mathrm dy^3}{\mathrm x}=\frac{\mathrm 3[(y^3)^2-2x^2]}{\mathrm 2xy^3+x^2}$
# ### $ 令y^3=u,则原方程化为\frac{\mathrm du}{\mathrm dx}=\frac{\mathrm 3u^2-6x^2}{\mathrm 2xu+x^2}=\frac{\mathrm {\frac{\mathrm 3u^2}{\mathrm x^2}}-6}{\mathrm {\frac{\mathrm 2u}{\mathrm x}}+1}，这是齐次方程，令$
# ### $\frac{\mathrm u}{\mathrm x}=z,则\frac{\mathrm du}{\mathrm dx}=z+x\frac{\mathrm dz}{\mathrm dx}，所以\frac{\mathrm 3z^2-6}{\mathrm 2z+1}=z+x\frac{\mathrm dz}{\mathrm dx},两边积分得(z-3)^7(z+2)^3=x^5c$
# ### $即（y^3-3x)^7(y^3+2x)^3=x^5c$
# ### $又因为y^3=3x或y^3=-2x包含在通解中$
# ### $当c=0时，故原方程的解为(y^3-3x)^7(y^3+2x)^3=x^{15} c$

# %% [markdown]
# ## $(7)\frac{\mathrm dy}{\mathrm dx}=\frac{\mathrm 2x^3+3xy^2+x}{\mathrm 3x^y+2y^3-y}$

# %% [markdown]
# ### $解：$
# ### $ 原方程化为\frac{\mathrm dy}{\mathrm dx}=\frac{\mathrm x(2x^2+3y^2+1}{\mathrm 3x^2+2y^2-1} \frac{\mathrm dy^2}{\mathrm dx^2}=\frac{\mathrm 2x^2+3y^2+1}{\mathrm 3x^2+2y^2-1}$
# ### $ 令y^2=u,x^2=v,则\frac{\mathrm du}{\mathrm dv}=\frac{\mathrm 2v+3u+1}{\mathrm 3v+2u-1}(1)$
# ### $ 方程组{2v+3u+1=0,3u+2v-1=0}的解为(-1,1)；令Z= v-1,Y=u+1,$
# ### $ 则有{2z+3y=0,3z+2y=0}从而方程(1)化为\frac{\mathrm dy}{\mathrm dz}=\frac{\mathrm 2+\frac{\mathrm 3y}{\mathrm z}}{\mathrm 3+\frac{\mathrm 2y}{\mathrm z}}$
# ### $ 令t=\frac{\mathrm y}{\mathrm z},则有\frac{\mathrm dy}{\mathrm dz}=t+z\frac{\mathrm dt}{\mathrm dz},所以t+z\frac{\mathrm dt}{\mathrm dz}=\frac{\mathrm 2+3t}{\mathrm 3+2t},z\frac{\mathrm dt}{\mathrm dz}=\frac{\mathrm 2-2t^2}{\mathrm 3+2t}(2)$
# ### $ 当2-2t^2=0时，即t=1或-1是方程（2）的解。得y^2=x^2-2或y^2=-x^2是原方程的解$
# ### $  当2-2t^2!=0时，分离变量得\frac{\mathrm 3
# =2t}{\mathrm 2-2t^2}dt=\frac{\mathrm 1}{\mathrm z}dz,两边积分得y^2+x^2=(y^2-x^2+2)^5c$
# ### $y^2=x^2-2或y^2=-x^2包含在其通解中$
# ### $故原方程的解为y^2+x^2=(y^2-x^2+2)^5c$

# %% [markdown]
# ## $设y_1(t)是dy/dt=f(y),y(0)=y_0的解，证明y_2（t)=y_1(t-t_0)是dy/dt=f(y),y(t_0)=y_o的解。$

# %% [markdown]
# ### $解：$
# ### $对y_2(t)=y_1(t-t_0)两边求导得：$
# ### $$dy_2(t)/dy=dy_1(t-t_0)/dt=dy_1(t-t_0)/d(t-t_0)=f(y_I(t-t_0))=f(y_2)$$
# ### $所以，y_2=y_1(t-t_0)也是dy/dt=f(y)的解$
# ### $由y_1(0)=y_0得，当t=0时，y_1(0)=y_0$
# ### $所以，t-t_0=0,t=t_0时$
# ### $$y_1(t-t_0)=y_0$$
# ### $又$
# ### $$y_2(t)=y_1(t-t_0)$$
# ### $所以$
# ### $$y_2(t)=y_2(t_0)=y_0$$

# %% [markdown]
# # <font color='red'>A  12/9
