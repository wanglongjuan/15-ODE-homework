# %% [markdown]
# 3.验证下列各函数是相应微分方程的解
#
# （7）$y=x^2$,$y'=y^2-(x^2+1)y+2x$
#
# 解：
# ∵$$y=x^2$$
#
# ∴$$y'=2x$$
#
# 又∵$$y'=y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x$$
#
# ∴$$y=x^2是方程y'=y^2-(x^2+1)y+2x的解$$

# %% [markdown]
# (8) $y=\frac{-g(x)}{f(x)}$,$y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$
#
# 解：
# ∵$$y=\frac{-g(x)}{f(x)}$$
# ∴$$y'=-\frac{g'(x)f（x)-g(x）f'(x)}{f(x)^2}=\frac{g(x)f'（x)-g'(x）f(x)}{f(x)^2}$$
# 又∵$$y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}=\frac{f'(x)}{g(x)}*\frac{[g(x)]^2}{[f(x)]^2}-\frac{g'(x)}{f(x)}=\frac{g(x)f'（x)-g'(x）f(x)}{f(x)^2}$$
#
# 所以$y=\frac{-g(x)}{f(x)}$是方程$y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$的解

# %% [markdown]
# 4.给定一阶微分方程$ \frac{dy}{dx}=2x $，
#
# （1）求出它的通解；
#
# （2）求通过点（1,4）的特解；
#
# （3）求出与直线$y=2x+3$相切的解；
#
# （4）求出满足条件$\int\limits_0^1 ydx=2$的解；
#
# （5）绘出（2），（3），（4）中的解的图形

# %% [markdown]
# （1）解：∵$$\frac{dy}{dx}=2x $$
# ∴$$dy=2xdx$$
# ∴由积分可得$$y=x^2+c（c为任意常数）$$
# ∴$$\frac{dy}{dx}=2x 的通解为y=x^2+c（c为任意常数）$$
# （2）解：将点（1，4）代入式子$y=x^2+c$
#
# ∴可得c=3
#
# ∴特解：y=x^2+3
#
# （3）解：∵与直线$y=2x+3$相切
#
# ∴即方程$y=x^2+c$与方程$y=2x+3$有且只有一个解
#
# 即$x^2+c=2x+3$有唯一解
# $$∴c=4$$
# ∴所求方程为$$y=x^2+4$$
# （4）解：由题：$\int\limits_0^1 ydx=2$可得：$\int\limits_0^1 (x^2+c)dx=2$
# $$∴c=\frac{5}{3}$$
# （5）解：

# %%
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 1.求下列方程的解
#
# （6）$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}=0$
#
# 解：令$\frac{y}{x}=u$
#
# 则$\frac{dy}{dx}=u+x\frac{du}{dx}$
#
# $\frac{1}{\sqrt{1-u^2}}du=sgnx$ $\frac{1}{x}dx$
#
# $arcsin\frac{y}{x}=sgnx$ $ln|x|+c$
#
#  $另外，y^2=x^2也是方程的解$
#
# （7）$\tan y dx-\cot x dy=0$
#
# 解：$\frac{dy}{tany}=\frac{dx}{cotx}$
#
#    $两边积分得：\ln |\sin y|=-\ln |\cos x|-ln|c|$
#
#    $siny= \frac{1}{c*cosx}=\frac{c}{cosx}$另外y=0也是原方程的解，而c=0时，y=0
#
#    所以原方程的通解为$sinycosx=c$

# %% [markdown]
# # <font color='red'>结果不对

# %% [markdown]
# 2.作适当的变量变换求解下列方程：
#
# （6）$\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$
#
# 解：$\frac{dy}{dx}=\frac{（y^3）^2-2x^2}{y^2(2xy^3+x^2)}=\frac{dy^3}{dx}=\frac{3[(y^3)^2-2x^2]}{2xy^3+x^2}$
#
# 令$y^3=u$则原方程化为：
#
# $\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}=\frac{\frac{3u^2}{x^2}-6}{\frac{2u}{x}+1}$这是齐次方程，令$\frac{u}{x}=z$
#
# 则$\frac{3z^2-6}{2z+1}=z+x\frac{dz}{dx}$
#
# $x\frac{dz}{dx}=\frac{z^2-z-6}{2z+1}$
#
# 当$z^2-z-6=0$时，得z=3或z=-2    $即y^3=3x或y^3=-2x是方程的解
#
# 当$z^2-z-6\not=0$时，变量分离再两边求积分：$(z-3)^7(z+2)^3=x^5c$
#
# 即$(y^3-3)^7(y^3+2)^3=x^5c$
#
# $又∵y^3=3x或y^3=-2x包含在通解中当c=0时。故原方程的解为(y^3-3)^7(y^3+2)^3=x^5c$
#
# (7)$\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}$
#
# 解：将原方程化为$\frac{dy}{dx}=\frac{x(2x^2+3y^2+1)}{y(3x^2+2y^2-1)}$
#
# $令y^2=u,x^2=v$
#
# 则$\frac{du}{dv}=\frac{2v+3u+1}{3v+2u-1}$
#
# 令q=v-1,p=u+1$
#
#    $则有\left\{\begin{array}\\2q+3p=0\\{3q+2p=0} \end{array}\right.可得\frac{dp}{dq}=\frac{2+3\frac{p}{q}}{3+2\frac{p}{q}}$
#
#    $令t=\frac{p}{q},则有\frac{dp}{dq}=t+z\frac{dp}{dq},所以t+q\frac{dt}{dq}=\frac{2+3t}{3+2t},q\frac{dt}{dq}=\frac{2-2t^2}{3+2t}$
#
#    $当2-2t^2=0,即t=\pm1 ,得y^2=x^2-2或y^2=-x^2是原方程的解$
#
#    $当2-2t^2\neq 0时，分离变量得\frac{3+2t}{2-2t^2}dt=\frac{1}{q}dq两边积分得y^2+x^2=(y^2-x^2+2)^5c$
#
#    $另外，y^2=x^2-2或y^2=-x^2,包含在其通解中，故原方程的解为y^2+x^2=(y^2-x^2+2)^5c$

# %% [markdown]
# 证明题：
#
# 证：$设y_1(t)是\frac{dy}{dt}=f(y),f(0)=y_0解$
#
# $则y_2(t)=y_1(t-t_0)是\frac{dy}{dt}=f(y),y(t_0)=y_0的解$
#
# $f(y_2(t))=f(y_1(t-t_0))=\frac{dy_1(t-t_0)}{dt}=\frac{dy_2}{dt}$
#
# $y_2(t_0)=y_1(0)=y_0$

# %% [markdown]
# # <font color='red'>A 12/9
