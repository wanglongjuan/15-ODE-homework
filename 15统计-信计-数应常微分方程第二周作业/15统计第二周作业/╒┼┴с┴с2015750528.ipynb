# %% [markdown]
#  # $$常微分作业$$
#  ## 班级：统计学1班       姓名：张玲玲       学号：2015750528
#
#  ## P(27)
#  ## 3、验证下列各函数是相应微分方程的解：
#  ##  （7）$y=x^2+1, y^\prime=y^2-(x^2+1)y+2x$;
#  ##  （8）$y=-\frac{g(x)}{f(x)},y^\prime=\frac{f^\prime(x)}{g(x)}y^2-\frac{g^\prime(x)}{f(x)}$.
#
#  证：
# （1）由 $y=x^2+1$ 得：
#
#  $y^\prime=2x$
#
#  将 $y=x^2+1$ 代入 $y^\prime=y^2-(x^2+1)y+2x$,得
#
#  $y^\prime=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x$
#
#  证毕。
#
# （2）由 $y=-\frac{g(x)}{f(x)}$ 得
#
#  $y^\prime=-\frac{g^\prime(x)f(x)-g(x)f^\prime(x)}{f(x)^2}$
#
#  将$y=-\frac{g(x)}{f(x)}代入y^\prime=\frac{f^\prime(x)}{g(x)}y^2-\frac{g^\prime(x)}{f(x)}$得：
#
#  $y^\prime=\frac(x){f^\prime(x)}{g(x)}(-\frac{g(x)}{f(x)})^2-\frac{g^\prime(x)}{f(x)}=-\frac{g^\prime(x)f(x)-g(x)f^\prime(x)}{f(x)^2}$
#
#  证毕。

# %% [markdown]
# ## P(27)
# ## 4、给定一阶微分方程 $\frac{dy}{dx}=2x$,
# ## （1）求出它的通解；
# ## （2）求通过点（1,4）的特解；
# ## （3）求出与直线 $y=2x+3$ 相切的解；
# ## （4）求出满足条件 $\int_0^1y\mathrm dx=2$ 的解；
# ## （5）绘出（2），（3），（4）中的解的图形。
#
# 解：
# （1）由 $\frac{dy}{dx}=2x$ 知
#
#  dy=2xdx,
#
#  则 $y=x^2+c$ (c为常数）
#
#  即知，它的通解为 $y=x^2+c$ .
#
# （2）将（1,4）代入 $y=x^2+c$,得
#
#  c=3
#
#  即 $y=x^2+3$
#
#  通过点（1,4）的特解为 $y=x^2+3$.
#
# （3）将 $y=2x+3$ 代入 $y=x^2+c$ 得：
#
#  $x^2+2x+c-2=0$
#
#  $b^2-4ac=(-2)^2-4(c-3)=0$
#
#  解得：c=4
#
#  即：$y=x^2+4$
#
#  即求出与直线 y=2x+3 相切的解为 $y=x^2+4$.
#
# （4）已知 $y=x^2+c$,代入 $\int_0^1y\mathrm dx=2$ 得
#
#  $\int_1^1x^2+c\mathrm dx=2$
#
#  解得 $c=\frac{5}{3}$
#
#  $y=x^2+\frac{5}{3}$
#
#  即满足条件 $\int_0^1y\mathrm dx=2$ 的解为 $y=x^2+\frac{5}{3}$.
#
# （5）

# %%
var('x_1')
y_1=x_1^2+3
plot(y_1,x_1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var ('x_2')
y_2=x_2^2+4
plot(y_2,x_2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var ('x_3')
y_3=x_3^2+5/3
plot(y_3,x_3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## 1、求下列方程的解：
# ## P(42)
# ## （6）$x\frac{dy}{dx}-y+\sqrt(x^2-y^2)=0$;|
#
# ## （7）$\tan y-\cot xdy=0$.
# 解：
# （6）将方程 $x\frac{dy}{dx}-y+\sqrt(x^2-y^2)=0$ 改写为 $\frac{y}{x}-\frac{\sqrt(x^2-y^2)}{x}$
#
#   以 $\frac{y}{x}=u$以及 $\frac{dy}{dx}=x\frac={du}{dx}+u$ 代入，得
#
#   $x\frac{du}{dx}=-\sqrt(1-u^2)$
#
#   分离变量，得
#
#   $-\frac{du}{\sqrt(1-u^2)}=\frac{dx}{x}$
#
#   两边积分，得
#
#   $-arcsinu=ln|x|+c$,代入 $u=\frac{y}{x}$ 得 $-arcsin\frac{y}{x}=ln|x|+c$ (c是任意常数）
#
#   此外，方程还有解 $-\sqrt(1-(u)^2)=0$ 即 $y^2=x^2$
#
#   综上，方程的解为 $-arcsin\frac{y}{x}=ln|x|+c$,$y^2=x^2$
#
#  （7）将变量分离得
#
#   $\frac{\mathrm dy}{dx}=\tan y\tan x$,$\frac{dy}{\tan y}=\tan xdx$
#
#   两边积分得
#
#   $lnsiny=-lncosx+c$(c是任意正常数）
#
#   此外，方程还有解$\tan x=0$即$y=kpi$,k是任意常数
#
#   即方程的解为$lnsiny=-lncosx+c$,$y=kpi$,k是任意整数。
#
# ## P(43)
# ## 2、做适当的变量变换求解下列方程：
# ## （6）$\frac{\mathrm dy}{\mathrm dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$；
# ## （7）$\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}$
#
# 解：
# （6）$\frac{dy}{dx}=\frac{(y^3)^2-2x^2}{y^2(2xy^3+x^2)}=\frac{dy^3}{dx}=\frac{3[(y^3)^2]}{2xy^3+x^2}$
#
#   令u=y^3,原方程变成$\frac{du}{dx}=\frac{3u^2-6x^2}{2ux-+x^2}=\frac{3u^2/x^2-6}{2u/x+1}$
#
#   令$z=\frac{u}{x}$则$\frac{du}{dx}=z+x\frac{dz}{dx}$
#
#   所以$\frac{3z^2-6}{2z+1}=z+x\frac{dz}{dx},x\frac{dz}{dx}=\frac{z^2-z-6}{2z+1}$
#
#   当$\frac{z^2-z-6}{2z+1}$等于0，得z=3或z=-2，$y^3=3x$或$y^3=-2x$是方程的解
#
#   当$\frac{z^2-z-6}{2z+1}$不等于0，
#
#   将变量分离得
#
#   $\frac{2z+1}{z^2-z-d}dz=\frac{1}{x}dx$
#
#   两边积分得
#
#   $(z-3)^7(z+2)^3=x^5c,代入y为（y^3-3x）(y^3+2x)^3=x^15c$
#
#   又因为$y^3=3x$或$y^3=-2x$包含在通解中
#
#   所以，解为$(y^3-3x)(y^3+2x)^3=x^{15}c$。
#
# （7）$\frac{dy}{dx}=\frac{x(2x^2+3y^2+1}{y3x^2+2y^2-1}$,$\frac{dy^2}{dx^2}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
#   令$y^2=u,x^2=v$
#
#   则$\frac{du}{dx}=\frac{2v+3u+1}{3v+2u-1}$
#
#   由方程$2v+3u+1=0$和$3v+2u-1=0$组成的方程组的解为（1，-1）
#
#   令$z=v-1,w=u+1,由2z+3w=0和3z+2w=0的方程组，化简为\frac{dw}{dz}=\frac{2+3w/z}{3+2w/z}$
#
#   令$t=\frac{w}{z}$,则有$\frac{dw}{dz}=t+z\frac{dt}{dz}$,所以$t+z\frac{dt}{dz}=\frac{2+3t}{3+2t}$,$z\frac{dt}{dz}=\frac{2-2t^2}{3+2t^2}$
#
#   当$2-2t^2=0$，即t=-1，得$y^2=x^2-2$或$y^2=-x^2$是方程的解$
#
#   当$2-2t^2$不等于0，将变量分离得:$\frac{3+2t}{2-2t^2}dt=\frac{1}{z}dz$
#
#   两边积分得
#
#   $y^2+x^2=(y^2-x^2+2)^5c$
#
#   因为$y^2=x^2-2$或$y^2=-x^2$包含在通解中
#
#   所以原方程的解为$(y^2+x^2)c=(y^2-x^2+2)^5$。

# %% [markdown]
# ## 补充题
# ## 1、说明“有理整式”的概念。
#
# 解：代数式的一种，有理数的次数为一，包括分式和整式。这种代数式中对于字母只进行有限次加、减、乘、除和正整数次乘方这些运算。
#
# ## 2、通解中，解对常数的独立性是指？
#
# 解：对函数f及其他的n-1阶偏导数关于n个常数c_1,c_2,……，c_n的雅可比行列式不等于0.
#
# ## 3、设$y_1(t)$是 $\frac{d y}{d t}=f(y),y(0)=y_0$的解,证明$y_2(t)=y_1(t-t_0)$是$\frac{d y}{d x}=f(y),y(t_0)=y_0$的解.
#
# 证明：
#
#   $\frac{dy_1(t)}{dt}=f(y_1(t)),y_1(0)=y_0$
#
#  因为$\frac{d(t-t_0)}{d(t)}=\frac{d(t-t_0)}{d(t-t_0)}=f(y_1(t-t_0))=f(y_2(t))$
#
#   $y_2(t_0)=y_1(t_0-t_0)=y_1(0)=y_0，即\frac{dy_2(t)}{dt}=f(y_2(t)),y_2(t_0)=y_0$
#
#  即$y_2(t)=y_1(t-t_0)$为$\frac{d y}{d t}=f(y)$,$y(t_0)=y_0$的解
#
#   证毕.

# %% [markdown]
# # <font color='red'>A+  12/9
