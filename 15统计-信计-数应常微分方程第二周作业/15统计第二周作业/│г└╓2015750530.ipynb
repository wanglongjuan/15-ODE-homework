# %% [markdown]
# 3.验证下列各函数是相应微分方程的解：
# （7）y=x^2+1，y'=y^2-(x^2+1)y+2x
#
# （8)y=-g(x)/f（x），y＇=f´（x)/g(x）y^2-g´(x)/f(x)
# 解;(7)$y=x^2+1,y'=2x$
#
# $y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x=y'$
#
# $因此，是方程的解$
#
# （8）## （8）##
# $y=\frac{-g(x)}{f(x)},y'=\frac{g'(x)f(x)-f'(x)g(x)}{-f^2(x)}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}$
#
# $又\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}=\frac{f'(x)}{g(x)}(\frac{-g(x)}{f(x)})^2-\frac-{g'(x)}{f(x)}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}=y'$
#
# $所以，得证$
#
# 4.给定一阶微分方程dy/dx=2x
#
# （1）求出它的通解
#
# （2）求通过点（1，4）的特解
#
# （3)求出与直线y=2x+3相切的解
# $（4）求出满足条$$\int_0^1ydx=2的解$
#
# （5)汇出（2）(3)(4）中的解得图形

# %% [markdown]
# $\frac{dy}{dx}=2x,得dy=2d方程两边同时积分，即得y=x^2+c，方程的解为y=x^2+c$
#
# $把点（1，4）代入方程得到c=3，所以方程的特解为y=x^2+3$
#
# $与直线相切，所以联立方程有唯一解，既方程x^2+c=2x+3有唯一解，解得c=4
#
# $\int_0^1\mathrm ydx=\int_0^1\mathrm (x^2+c)dx=\frac{1}{3}+c=2,解得c=\frac{5}{3}$

# %%
var('x y')
y=x^2+3
show(y)
plot(y)
# Out:
# x^2 + 3
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+4
show(y)
plot(y)
# Out:
# x^2 + 4
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+5/3
show(y)
plot(y)
# Out:
# x^2 + 5/3
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $P42   1（6）
#
# $原方程变形为xdy-ydx+（x^2-y^2)\frac{1}{2}dx=0,,当y^2=x^2时，移项，两边同时积分得y^2=x^2是方程的解$
#
# $当y^2不等于x^2时，两边同时除以（x^2-y^2）^\frac{1}{2}得到\frac{xdy-ydx}{x^2+y^2)\frac{1}{2}+dx=0$
#
# $即\frac{d（\frac{y}{x}）}{1-（\frac{y}{x}^2）}+\frac{1}{x}dx=0$
#
# $两边积分得arcsin\frac{y}{x}+lnx=c$
#
# $方程的解为：arcsinfrac{y}{x}+ln|x|=c与y^2=x^2$

# %% [markdown]
# （7）
#
# $当y不等于πk时，分离变量有cotydy=tanxdx同时积分得到ln|siny|=-ln|cosx|+c1,c1是常数$
#
# $sinycosx=c是方程的解$
#
# $y=kπ时，k=0，1，-1，2，-2……与sinycosx=c$

# %% [markdown]
# P43  2（6）
#
# $\frac{dy}{dx}=frac{y^6-2x^2}{2xy^5+x2y^2}$
#
# $可变形为\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$
#
# $最后整理得\frac{7}{5}\frac{dv}{v-3}+\frac{dv}{v+2}=\frac{dx}{x}$
#
# $两边同时积分得（v-3)^7(v+2)^3=cx^5,c是常数$

# %% [markdown]
# # <font color='red'>结果回带

# %% [markdown]
# （7）
# $\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y^3-y}$
#
# $原方程可以化为\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# $再令u=x^2-1,v=y^2+1,则方程可以化为\frac{dv}{du}=\frac{2u+3v}{3u+2v}$
#
# $分离变量\frac{4}{u}du=（\frac{5}{1-w}+\frac{1}{1+w}）$
#
# $两边积分得u^4（1-w）^5=c（1+w）$
#
# $代会原变量得原方程的解为(x^2-y^2-2)^5=c(x^2+y^2),是任意常数c$

# %% [markdown]
# # <font color='red'>B  12/9 黑板验证题
