# %% [markdown]
# 3.验证下列各函数是相应微分方程的解
#
# $（7）y=x^2+1,y＇=y^2-(x^2+1)y+2x;$
#
# $解：因为y=x^2+1,y＇=2x$
#
# $将y=x^2+1代入方程y＇=y^2-(x^2+1)y+2x中,得:$
#
# $（x^2+1）^2-(x^2+1)(x^2+1)+2x=2x=y＇=2x,$
#
# $所以y=x^2+1是方程y＇=y^2-(x^2+1)y+解.$
#
# $（8）y=-g(x)/f(x),y＇=(f＇（x）/g(x))y^2-g＇(x)/f(x）.$
#
# $将y=-g(x)/f(x)代入方程y＇=(f＇（x）/g(x))y^2-g＇(x)/f(x）,$
#
# $(f＇(x)/g(x))*(g^2(x)/f^2(x))-g＇(x)/f(x)=(f＇（x）g(x)-g＇(x)f(x))/f^2(x)得:$
#
# $y＇=(-g＇(x)f(x)+f＇（x）g(x))/f^2(x),$
#
# $所以y＇=(f＇(x)/g(x))*(g^2(x)/f^2(x))-g＇(x)/f(x),$
#
# $故y=-g(x)/f(x)是方程y＇=(f＇（x）/g(x))y^2-g＇(x)/f(x）的解.$
#
# $4.给定一阶微分方程dy/dx=2x,
# (1)求出它的通解；
# （2）求通解过点（1,4）的特解；
# （3）求出与直线y=2x+3相切的解；
# （4）求出满足条件
# \int_1^2\mathrm y\,\mathrm{d}x$=2的解；
# (5)绘出（2），（3），（4）中的解的图形.
#
# $解：(1)由dy/dx=2x得dy=2xdx,方程两边积分得y=x^2+c(c为常数),所以方程dy/dx=2x的通解为y=x^2+c(c为常数).$
#
# $(2)将x=1,y=4代入方程y=x^2+c得c=3.所以过点（1,4）的特解为y=x^2+3.$
#
# $(3)因为与直线相切，所以方程组y=x^2+c，y=2x+3只有一组解，x^2+cy=2x+3得c=4,所以与直线相切的解为y=x^2+4.$
#
# $(4)因为\int_0^1\mathrm y\,\mathrm{d}$x=$\int_0^1\mathrm (x^2+c)\,\mathrm{d}$x=1/3+c,得c=5/3,所以满足条件$\int_1^2\mathrm y\,\mathrm{d}x$=2的解为y=x^2+5/3.$

# %%
(5)var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $1.求下列方程的解：$
#
# （6）x(dy/dx)-y+（x^2-y^2）^(1/2)=0
#
# $解;在方程的两边同时乘以dx得$
#
# xdx-ydx+（x^2-y^2）^(1/2)dx=0,
#
# 当y^2≠x^2时,两边同时除以（x^2-y^2）^(1/2) 得:
#
# $（xdy-ydx）/[(x^2-y^2)^(1/2)]+dx=0,$
#
# $两边积分得:$
#
# $arcsin(y/x)+ln|x|=c,c为常数.$
#
# $当y^2=x^2时，经验证得:$
#
# $y^2=x^2也是方程的解.$
#
# $综上述得方程的解为arcsin(y/x)+ln|x|=c和y^2=x^2$.
#
#
# (7)tan ydx-cot xdy=0
# $解：当tan y≠0也y≠kπ,k=0,±1，±2，…时分离变量得:$
#
# $cot ydy=tan xdx.$
#
# $两边同时积分得:$
#
# $ln|sin y|=ln|cos x+c1(c1为常数).
#
# 即sin ycos x=c,c=±e^c1为非零常数.
#
# $同时y= kπ, k=0,±1，±2，…也是方程的解.$
#
# 总上述得方程的解为sin ycos x=c和k=0,±1，±2，….
#
# $2．作适当的变量变换求解下列方程：$
#
# $（6）dy/dx=(y^6-2x^2)/（2xy^5+x^2y^2）;$
#
# $解：令u=y^3,则原方程变为:$
#
# $du/dx=(3u^2-6)/(2xu+x^2),$
#
# $在令v=u/x,则u=vx,代入上述方程得:$
#
# $x（dv/dx）+v=(3v^2-6)/(2v+1)$
#
# $再两边同时积分得:$
#
# $（v-3）^7(v+2)^3=cx^5(c为正常数).$
#
# $代回原变量并化简，得方程的解为:$
#
# $（y^3-3x）^7(y^3+2x)^3=cx^(15).$
#
# $(7)dy/dx=(2x^3+3xy^2+x)/(3x^2y+2y^3-y).$
#
# $令u=x^2-1,v=y^2+1则可将方程化为：$
#
# $dv/du=(2u+3v)/(3u+2v),$
#
# $再令w=v/u,即v=uw,则有dv/du=w+u(dw/du),故u(dw/du)=(2-2w^2)/(3+2w),$
#
# $分离变量并化简得:$
#
# $(4/u)du=(5/（1-w）+1/(1+w))dw,$
#
# $两边同事积分得u^4(1-w)^5=c(1+w),$
#
# $代回原变量得元方程的解为:$
#
# $（x^2-y^2-2）^5=c(1+w),c为任意常数.$
#
# 课堂作业
# $设y_1(t)是du/dt=f(x),y(0)=y_0的解，证明y_2(t)=y_1(t-t_0)是dy/dt=f(y),y(t_0)=y_0的解.$
#
# $解： dy_2(t)/dt=dy_1(t-t-0)=dy_1(t-t-0)/d(t-t_0)=f(y_1(t-t_0))=f(y_2),$
#
# $所以y_2=y_1(t-t_0)也为\frac{dy}{dt}=f(y)的解,$
#
# $因y_1(0)=y_0,得出t=0时，y_1(0)=y_0,$
#
# $所以t-t_0=0时，y_1(t-t_0)=y_0,y_2(t_0)=y_0.$

# %% [markdown]
# # <font color='red'>A 12/9  （7） 结果中w??
