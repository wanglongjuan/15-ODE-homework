# %% [markdown]
# 9月6日
#
# P27
#
# 3.验证下列函数是相应微分方程的解。
#
# （7）$ y=x^2+1  ，  y^{\prime}=y^2-(x^2+1)y+2x $
#
# 因为 $ y=x^2+1 $
#
# 所以 $ y^{\prime}=2x $
#
# $ 将 y、y^{\prime}带入原方程。右边=（x^2+1）^2-(x^2+1)(x^2+1)+2x=2x=左边 $
#
# 所以 $ y=x^2+1 $ 是原方程的解

# %% [markdown]
# （8）$ y=-\frac{g(x)}{f(x)} ,  y^{\prime}=\frac{f{\prime}(x)}{g(x)}y^2-\frac{g{\prime}(x)}{f(x)} $
#
# 因为 $ y=-\frac{g(x)}{f(x)} $
#
# 所以 $ y^{\prime}=\frac{g(x)f{\prime}(x)-g{\prime}(x)f(x)}{f^2(x)} $
#
# 带入原方程，$ 右边=\frac{f{\prime}(x)g(x)}{f^2(x)}-\frac{g{\prime}(x)}{f(x)}=\frac{g(x)f{\prime}(x)-g{\prime}(x)f(x)}{f^2(x)}=左边 $
#
# 所以 $ y=-\frac{g(x)}{f(x)} $ 是原方程的解

# %% [markdown]
# 4.给定一阶微分方程$ \frac{\mathrm{dy}}{\mathrm{dx}}=2x $
#
# (1)求出它的通解
#
# 因为 $ \frac{\mathrm{dy}}{\mathrm{dx}}=2x $
#
# 所以 $ \mathrm{dy}=2x\mathrm{dx} $
#
# 两边积分 $ \int \mathrm{dy}=\int 2x\mathrm{dx} $
#
# 得, $ y=x^2+c $
#
# 所以通解为$ y=x^2+c $
#
# (2)求通过点（1,4）的特解
#
# 代入(1,4)，得4=1+c，c=3
#
# 所以特解为$ y=x^2+3 $
#
# （3）求出与直线$ y=2x+3 $相切的解
#
# $ k=y^{\prime}=2 $
#
# 所以$ y=x^2+c 在（x,y）的斜率为 y^{\prime}=2x=k=2 $
#
# 所以$ x=1，y=2+3=5 $
#
# 代入，得$ c=4 $
#
# 所以解为$ y=x^2+4 $
#
# （4）求出满足条件$ \int\limits_0^1 y\mathrm{dx}=2 $的解
#
# $ \int\limits_0^1 y\mathrm{dx}=\int\limits_0^1(x^2+c)\mathrm{dx}=\left.(\frac{x^3}{3}+cx)\right|_0^1=\frac{1}{3}+c=2 $
#
# 所以c=3
#
# 所以$ y=x^2+\frac{5}{3} $
#
# （5）绘出（2）、（3）、（4）中解的图形

# %%
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 9月7日
#
# P42
#
# 1.求下列方程的解。
#
# （6）$ x\frac{\mathrm{dy}}{\mathrm{dx}}-y+\sqrt{x^2-y^2}=0 $
#
# $ \frac{\mathrm{dy}}{\mathrm{dx}}-\frac{y}{x}+\sqrt{1-(\frac{y}{x})^2}=0 $
#
# 令$ \frac{y}{x}=u，y=ux $
#
# 所以$ \frac{\mathrm{dy}}{\mathrm{dx}}=x\frac{\mathrm{du}}{\mathrm{dx}}+u $
#
# 所以$ x\frac{\mathrm{du}}{\mathrm{dx}}+\sqrt{1-u^2}=0 $
#
# $ \frac{\mathrm{du}}{\sqrt{1-u^2}}=-\frac{\mathrm{dx}}{x} $
#
# 两边积分，得$ \arcsin u+\ln{|x|}=c $
#
# 所以原方程的解为$ \arcsin \frac{y}{x}+\ln{|x|}=c $
#
# 又因为$ u^2=1 $为方程的解
#
# 所以原方程还有解$ y=±x $

# %% [markdown]
# （7）$ \tan y \mathrm{dx}- \cot x \mathrm{dy}=0 $
#
# $ \tan y≠0时，有\frac{\mathrm{dy}}{\tan y}=\frac{\mathrm{dx}}{\cot x} $
#
# 即$ \cot y \mathrm{dy}=\tan x \mathrm{dx} $
#
# 两边积分，得$ \ln{|\sin y|}+\ln{|\cos x|}=c $
#
# $ \sin y\cos x=c $
#
# 当$ \tan y=0时，y=nπ，n=0、±1、±2……也是原方程的解 $

# %% [markdown]
# 2.作适当的变量代换求解下列方程。
#
# （6）$ \frac{\mathrm{dy}}{\mathrm{dx}}=\frac{y^6-2x^2}{2xy^5+x^2y^2} $
#
# 令$ u=y^3，则\mathrm{dy}=\frac{1}{3y^2} $
#
# 所以$ \frac{\mathrm{du}}{\mathrm{dx}}=\frac{3u^2-6x^2}{2xu+x^2}=\frac{3(\frac{u}{x})^2-6}{2\frac{u}{x}+1} $
#
# 令$ \frac{u}{x}=z，u=xz $
#
# 所以$ \frac{\mathrm{du}}{\mathrm{dx}}=x\frac{\mathrm{dz}}{\mathrm{dx}}+z $
#
# 所以$ z+x\frac{\mathrm{dz}}{\mathrm{dx}}=\frac{3z^2-6}{2z+1} $
#
# $ x\frac{\mathrm{dz}}{\mathrm{dx}}=\frac{z^2-z-6}{2z+1} $
#
# 当$ z^2-z-6=0时，即z=3或z=-2时，y^3=3x或y^3=-2x为方程的解。 $
#
# 当$ z^2-z-6≠0时，\frac{2z+1}{z^2-z-6}\mathrm{dz}=\frac{1}{x}\mathrm{dx} $
#
# 两边求积分，得$（z-3）^7（z+2）^3=x^5c $
#
# 所以$ （y^3-3x）^7（y^3+2x）^3=x^{15}c $为原方程的解

# %% [markdown]
# （7）$ \frac{\mathrm{dy}}{\mathrm{dx}}=\frac{2x^3+3xy^2+x}{3x^y+2y^2-y} $
#
# $ \frac{\mathrm{dy}}{\mathrm{dx}}=\frac{x(2x^2+3y^2+1)}{y(3x^2+2y^2-1)} $
#
# 即$ \frac{\mathrm{d(y^2+1)}}{\mathrm{d(x^2+1)}}=\frac{2(x^2-1)+3(y^2+1)}{3(x^2-1)+2(y^2+1)} $
#
# 令
# $ \begin{cases}
#    t=x^2-1\\
#    s=y^2+1
#   \end{cases} $
#
# $ \frac{\mathrm{ds}}{\mathrm{dt}}=\frac{2t+3s}{3t+2s} $
#
# 令$ \frac{s}{t}=a，s=at $
#
# 所以$ \frac{\mathrm{ds}}{\mathrm{dt}}=t\frac{\mathrm{da}}{\mathrm{dt}}+a $
#
# $ t\frac{\mathrm{da}}{\mathrm{dt}}=\frac{2-2a^2}{3+2a} $
#
# $ \frac{3+2a}{2(1-a^2)}\mathrm{da}=\frac{1}{t}\mathrm{dt} $
#
# 两边积分，得$ -\frac{5}{4}\ln{|1-a|}+\frac{1}{4}\ln{|1+a|}=\ln{|t|}+c $
#
# 即$ 1+a=ct^4(1-a)^5 $
#
# 即$ t+s=c(t-s)^5 $
#
# 所以通解为$ x^2+y^2=c(x^2-y^2-2)^5 $

# %% [markdown]
# 证明题：设$ y_1(t)是\frac{\mathrm{dy}}{\mathrm{dt}}=f(y)，y(0)=y_0的解，证明y_2(t)=y_1(t-t_0)是\frac{\mathrm{dy}}{\mathrm{dt}}=f(y)，y(t_0)=y_0的解 $
#
# $\frac{\mathrm{dy_2(t)}}{\mathrm{dt}}=\frac{\mathrm{dy_1(t-t_0)}}{\mathrm{dt}}=\frac{\mathrm{dy_1(t-t_0)}}{\mathrm{d(t-t_0)}}
# =f(y_1(t-t_0))=f(y_2) $
#
# 所以$ y_2=y_1(t-t_0)也为\frac{\mathrm{dy}}{\mathrm{dt}}=f(t)的解 $
#
# $ 由y_1(0)=y_0，得 $
#
# $ 即 t=0 时，y_1(0)=y_0 $
#
# 所以$ t-t_0=0时 y_1(t-t_0)=y_0 $
#
# 所以$ y_2(t_0)=y_0 $

# %% [markdown]
# # <font color='red'>A  12/9
