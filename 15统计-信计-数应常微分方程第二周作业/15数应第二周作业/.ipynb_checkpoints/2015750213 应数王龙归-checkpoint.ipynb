# %% [markdown]
# 一、验证下列各函数是相应微分方程的解：
# (7)$y=x^2+1,y'=y^2-(x^2+10）y+2y$
#
# (8)$y=-\frac{g(x)}{f(x)},y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$

# %% [markdown]
# 解;（7）对1方程求导可得$$y=2x$$
#
# 将1式平方可得$$y^2=x^4+2x^2+1$$
#
# 再将上式代入2式可得$$y^2-(x^2+1)y+2x=2x=y'$$
#
# 故方程1是微分方程2的解
#
# 解;(8)对1式求导可得$$y'=-\frac{g'(x)f(x)-f'(x)g(x)}{f^2(x)}$$
#
# 将1式平方可得3式$$y^2=\frac{g^2(x)}{f^2(x)}$$
#
# 将3式代入2式可知$$\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}=-\frac{g'(x)f(x)-f'(x)g(x)}{f^2(x)}=y'$$
#
# 故方程1是微分方程的解

# %% [markdown]
# 二、求下列方程的解：（6）$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}$
#
# (7)$tanydx-cotxdy=0$

# %% [markdown]
# （6）解对方程变形可得$$\frac{dy}{dx}=\frac{y}{x}-\sqrt{1-(\frac{y}{x}^2)}$$
#
# 令$\frac{y}{x}=u$
#
# 则上式可化为$$\frac{dy}{dx}=u-\sqrt{1-u^2}$$
#
# 分离变量可得：$$\frac{du}{\sqrt{1-u^2}}=-\frac{dx}{x}$$
#
# 对两边分别积分可得：$$arcsin\frac{y}{x}=ln|x|+c,其特解为y^2=x^2$$

# %% [markdown]
# (7)将方程变形并分离变量可得：$$cotydy=tanxdx$$
#
# 对两边同时积分可得：$$ln|sinx|=-ln|cosx|+a,进一步可以得到sinxcosx=c,其中y=kπ,k属于整数$$

# %% [markdown]
# 三、做适当的变量变换求解下列方程：
# (6)$\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}:$
#
# (7)$\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}:$

# %% [markdown]
# 解（6）令$u=y^3,则$$$\frac{du}{dx}=\frac{du}{dy}\frac{dy}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$$
#
# 再令$u=tx则$$$\frac{dt}{dx}=\frac{\frac{du}{dx}-t}{x}=\frac{1}{x}\frac{t^2-t-6}{2t+1}$$
#
# 分离变量再对两边积分可得：$$(y^3-3x)^7(y^3+2x)^3=cx^15$$
#
# 解（7）令$u=y^2则$$$\frac{du}{dx}=\frac{du}{dy}\frac{dy}{dx}=\frac{4x^3+6xu+2x}{3x^2+2u-1}$$
#
# 再另$x^2=k则$$$\frac{du}{dk}=\frac{du}{dx}\frac{dx}{dk}=\frac{2k+3u+2}{3k+2u-1}$$
#
# 然后令$X=x-1,Y=y+1$则$$\frac{2X+3Y}{3X+2Y}=\frac{du}{dk}$$
#
# 最后令$t=\frac{Y}{X}$则$$\frac{du}{dk}=k\frac{dt}{dk}+t$$
#
# 也即$$4\frac{dk}{k}=[\frac{5}{1-t}+\frac{1}{1+w}dt$$
#
# 两边积分再迭代回原式可得$$x^2+y^2=c(x^2-y^2-2)^5,c为任意常数$$

# %% [markdown]
# 四、给定一阶微分方程$\frac{dy}{dx}=2x,$（1）求出它的通解；（2）求出通过点（1，40的特解（3）求出与直线$y=2x+3$相切的解；（4）求出满足条件$\int_0^1ydx=2的解$:(5)绘出（2）、（3）、（4）中的解的图形.

# %%
var('x y c')
f = 2*x
F = integral(f,x)
show(F)
S=y==F+c
show(S)
# Out:
# x^2
# y == x^2 + c

# %% [markdown]
# (2)过（1，4）时，c=3,特解为$y=x^2+3$

# %% [markdown]
# (3)将$y=2x+3代入y=x^2+c,根据\Delta=0可得c=4，即y=x^2+4$\\

# %% [markdown]
# (4)将$y=x^2+c代入方程可得\frac{1}{3}x^3+cx|_0^1=2,c=\frac{5}{3}$
#
# 即$$y=x^2+\frac{5}{3}$$

# %%
var('x y')
y=x^2+3
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+4
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+5/3
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # <font color='red'>A 12/9
