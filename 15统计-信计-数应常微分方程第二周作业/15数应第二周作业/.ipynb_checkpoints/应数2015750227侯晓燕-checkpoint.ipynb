# %% [markdown]
# 3.验证下列各函数是相应微分方程的解
#
# （7）$y=x^2+1,y'=y^2-(x^2+1)y+2x$
#
#   对y求导得 $$\frac{dy}{dx}=2x$$
#
#   把$y=x^2+1$代入$y^2-(x^2+1)y+2x$得
#    $$y^2-(x^2+1)y+2x$$
#    $$=(x^2+1)^2-(x^2+1)(x^2+1)+2x$$
#    $$=2x$$
#    $$=y'$$
#    $$所以y=x^2+1是y'=y^2-(x^2+1)y+2x微分方程的解$$
#   （8）$y=\frac{-g(x)}{f(x)},y'=\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}$
#
#   对y求导$$y'=-\frac{g'(x)f(x)-g(x)f'(x)}{f(x)^2}$$
#   把$y=\frac{-g(x)}{f(x)}$代入$\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}$
#   $$\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}=\frac{f'(x)(\frac{-g(x)}{f(x)})^2}{g(x)}-\frac{g'(x)}{f(x)}$$
#   $$=\frac{f'(x)[g(x)]^2}{g(x)[f(x)]^2}-\frac{g'(x)}{[f(x)]^2}$$
#   $$=\frac{f'(x)g(x)}{[f(x)]^2}-\frac{g'(x)}{f(x)}$$
#   $$=-\frac{g'(x)f(x)-g(x)f'(x)}{f(x)^2}$$
#   $$=y'$$
#    $$所以y=\frac{-g(x)}{f(x)}是y'=\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}微分方程的解$$

# %% [markdown]
# 4、给定一阶微分方程$\frac{dy}{dx}=2x$,
#
# （1）求出它的通解；
#
# （2）求出通过点（1，4)的特解；
#
# （3）求出与直线$y=2x+3$相切的解；
#
# （4）求出满足条件$\int_0^1ydx=2$的解；
#
# （5）绘出（2）、（3）、（4）中的解的图形。
#
# (1)变量分离得到$$dy=2xdx$$
#
# $$y=x^2+c$$
#
# 则方程的通解为$y=x^2+c$
#
# (2)把点（1，4)代入方程$y=x^2+c$得到
#
# $$y=4,x=1$$
# $$4=1+c$$
#
# 求出$$c=3$$
#
# 把c=3代入方程$$y=x^2+3$$
#
# (3)对$y=x^2+c$求导，得到
#
# $$y_1'=2x$$
#
# 对$y=2x+3求导，得到
#
# $$y_2'=2$$
#
# 联立方程组
#
# $$
# \begin{cases}
# x^2+c=2x+3\\
# 2x=2\\
# \end{cases}
# $$
# 解得
# $$
# \begin{cases}
# x=1\\
# c=4\\
# \end{cases}
# $$
#
# 把解代入方程
#
# $$y=x^2+4$$
# (4)$$\int_0^1\mathrm y\,\mathrm{d}x=2$$
# 把$y=x^2+c$代入，得到
# $$\int_0^1\mathrm y\,\mathrm{d}x=\int_0^1\mathrm (x^2+c)\,\mathrm{d}x$$
# $$=(\frac{1}{3}x^3+cx)|_0^1$$
# $$=\frac{1}{3}+c$$
# $$\frac{1}{3}+c=c$$
# $$c=\frac{5}{3}$$
#
# 把$c=\frac{5}{3}$代入$y=x^2+c$,得到$y=x^2+\frac{5}{3}$
# $$所以\int_0^1ydx=2的解为y=x^2+\frac{5}{3}$$
#
# （5）绘出（2）、（3）、（4）中的解的图形。

# %%
var('x y ')
y=x^2+3
plot(y ,(x,-13,13))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y ')
y=x^2+4
plot(y ,(x,-14,14))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y ')
y=x^2+5/3
plot(y ,(x,-15,15))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 1、求下列方程的解：
#
# （6）$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}=0$；
#
# （7）$tanydx-cotxdy=0$；

# %% [markdown]
# 解：(6)令$$u=\frac{y}{x}$$
#  则$$\frac{y}{x}=\frac{xdu}{x}+u$$
#  把上面两个式子代入$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}=0$
#  得到$$\frac{xdu}{dx}=-\sqrt{1-u^2}$$
#  整理得$$\frac{du}{dx}=-\frac{\sqrt{1-u^2}}{x}$$
#  $$-\frac{1}{x}dx=\frac{1}{\sqrt{1-u^2}}du$$
#  对两边同时积分$$-ln|x|=arcsin(u)+c$$
#  即$$-ln|x|=arcsin(\frac{y}{x})+c，c为任意常数$$
#  $$又因为当\frac{y}{x}=1时，y^2=x^2也是方程的解$$
#  所以$-ln|x|=arcsin(u)+c，y^2=x^2$为$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}=0$的解

# %% [markdown]
# （7）当y≠kπ时，原式整理得$$tanxdx=\frac{1}{tany}dy$$
#  对两边同时积分得$$ln|siny|=-ln|cosx|+c$$
#  $$当y=kπ时，tanydx-cotxdy=0，故其为方程的解$$
# $$ 所以ln|siny|=-ln|cosx|+c，tanydx-cotxdy=0为tanydx-cotxdy=0的解$$

# %% [markdown]
# 2、做适当的变量变换求解下列方程：
#
# (6)$\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}:$
#
# (7)$\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}:$

# %% [markdown]
# 解：(6)令u=y^3,得$$\frac{dy}{dx}=\frac{u^2-2x^2}{2xu^\frac{5}{3}+x^2u^\frac{2}{3}}$$
# 又因为$$\frac{du}{dy}=\frac{du}{\frac{1}{3}u^\frac{-2}{3}}$$
# 所以$$\frac{du}{dx}=\frac{du}{dy}\frac{dy}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$$
# 令u=zx,得到$$z+x\frac{dz}{dx}=\frac{3z^2-6}{2z+1}$$

# %% [markdown]
# 分离变量得$$\frac{2z+1}{z^2-z-6}dz=\frac{-1}{x}dx$$

# %% [markdown]
# 两边同时积分得$$(y^3+2x)^3(y^3-3x)^7=cx^{15},c为任意常数$$

# %% [markdown]
# (7)将等式两边同时乘以$\frac{2y}{2x}$,得$$\frac{2y}{2x}\frac{dy}{dx}=\frac{2y}{2x}\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}$$

# %% [markdown]
# 整理得到$$\frac{dy^2}{dx^2}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$$

# %% [markdown]
# 令$a=x^2+1,b=y^2-1$,代入上式方程可得到$$\frac{2a+3b}{3a+2b}=\frac{b}{a}\frac{da}{db}$$

# %% [markdown]
# 令$e=\frac{a}{b}$,有$$\frac{2e+3}{3e+2}=e^2$$

# %% [markdown]
# 对两边同时积分，得到$$x^2+y^2=k(x^2-y^2-2)^5,k为任意实数$$

# %% [markdown]
# 3、设$y_1(t)$是$\frac{dy}{dx}=f(y),y(0)=y_0的解,$证明$y_2(t)=y_1(t-t_0)是\frac{dy}{dt}=f(y),y(t_0)=y_0的解$。

# %% [markdown]
# 由题意$y_1(t)$是$\frac{dy}{dx}=f(y),y(0)=y_0$的解

# %% [markdown]
# 可知$$\frac{dy_1(x)}{dx}=f(y_1)$$

# %% [markdown]
# 可知$$\frac{dy_1(x)}{dx}=f(y_1)$$

# %% [markdown]
# 由于$y_2(t)=y_1(t-t_0)$
# 所以$$\frac{dy_2(t)}{dt}=\frac{dy_1(t-t_0)}{dt}$$

# %% [markdown]
# $令x=t-t_0$
# 则$$\frac{dy_1(t-t_0)}{dt}=f(y_1(t-t_0))$$

# %% [markdown]
# $$\frac{dy_2(x）}{d（x）}=f(y_2)$$
# $$所以y_2(t)=y_1(t-t_0)是\frac{dy}{dt}=f(y)的解$$
# 有$$y_1(0)=y_0$$
# 令$t=t_0$得$$y_2(t_0)=y_1(t_0-t_0)$$
# $$=y_1(0)$$
# $$=y_0$$
# 所以$$y_2(t)=y_1(t-t_0)是y(t_0)=y_0的解$$

# %% [markdown]
# # <font color='red'>A  12/9
