# %% [markdown]
# 焦畅  2015750325

# %% [markdown]
# 3（7）
# $因为y=x^2+1$
#
# $所以左边=y'=2x $
#
# $右边=y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x$
#
# $因为左边=右边    所以此函数是微分方程的解$

# %% [markdown]
# (8)$左边=y'=\frac{g(x)f'(x)-f'(x)g'(x)}{f^2(x)}$
#
# $右边=\frac{f'(x)}{g(x)}y^2-\frac{g^2(x)}{f(x)}=\frac{f'(x)g^2(x)}{g(x)f^(x)}-\frac{g'(x)}{f(x)}=\frac{g(x)f'(x)-f'(x)g'(x)}{f^2(x)}$
#
# $所以左边等于右边  是微分方程的解$

# %% [markdown]
# 4(1)$因为y'=2x  所以y=\int\mathrm{2x}\,\mathrm{d}x=x^2+c$

# %% [markdown]
# (2)$(1,4)代入y=x^2+c中$
# $得到c=3,所以y=x^2+3$

# %% [markdown]
# （3）$y=2x+3中斜率为2，当y'=2时，x=1,代入y=2x+3得y=5$
# $将（1，5）代入y=x^2+c得c=4,所以y=x^2+4$

# %% [markdown]
# （4）$\int_0^1\mathrm y\,\mathrm{d}x=\int_0^1\mathrm{(x^2+c)}\,\mathrm{d}x=1/3+c=2 得c=5/3,所以y=x^2+5/3$

# %%
(5)
var('x')
f(x)=x^2+3
plot(f,(x,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f,(x,-8,8))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f,(x,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 1(6)
# $两边同除以x得到，\frac{d(y)}{d(x)}=\frac{y}{x}-\sqrt{1-(\frac{y}{x})^2}$
#
# $令\frac{y}{x}=u,由x\frac{du}{dx}+u=\frac{dy}{dx}$
#
# $得-\frac{du}{\sqrt{1-u^2}}=\frac{dx}{x}+c$
#
# $得  arcsin\frac{y}{x}+ln|x|=c$
#
# $u^2=1也是方程的解，所以原方程的解有y=x或y=-x$
#
# $所以原方程的解为y^2=x^2及arcsin\frac{y}{x}+ln|x|=c$

# %% [markdown]
# （7）$tant y不等于0时，即y不等于k \pi,k=...-2,-1,0,1,2...时$
#
# $分离变量得cot ydy=tant xdx$
#
# $两边同时积分，即得ln|sin y|=-ln|cosx|+c1,其中c1为任意常数$
#
# $即sin ycos x=c,其中c=e^c1和c=-e^c1为非零常数$
#
# $另外，y=k \pi,k=...-2,-1,0,1,2...也是方程的解$
#
# $所以，原方程的解为sin ycos x=c及y=kpi,k=...-2,-1,0,1,2...$

# %% [markdown]
# 2(6)$令u=y^2,则方程可变形为\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$
#
# $再令v=\frac{u}{x},即u=ux,则上面方程化为x\frac{dv}{dx}+v=\frac{3v^2-6}{2v+1},$
#
# $得，7/5\frac{dv}{v-3}+3/5\frac{dv}{v+2}=\frac{dx}{x},$
#
# $两边积分，(v-3)^7(v+2)^3=cx^5,其中c为正常数$
#
# $原方程的解为(y^3-3x)^7(y^3+2x)^3=cx^{15}$

# %% [markdown]
# (7)$原方程可以变形为\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1},$
#
# $令u=x^2-1,v=y^2+1,方程可化为\frac{dv}{du}=\frac{2u+3v}{3u+2v}$
#
# $令w=\frac{v}{u},即v=uw,则有\frac{dv}{du}=w+u\frac{dw}{du},则u\frac{dw}{du}=franc{2-2w^2}{3+2w}$
#
# $分离变量并简化得\frac{4}{u}du=(\frac{5}{1-w}+\frac{1}{1+w})dw$
#
# $两边积分u^4(1-w)^5=c(1+w),$
#
# $代回原变量即得原方程的解为（x^2-y^2-2）^5=c(x^2+y^2),其中c为任意常数$

# %% [markdown]
# $问：设y_1(t)是\frac{dy}{dt}=f(y),y(0)=y_0的解，证明y_2(t)=y1(t-t_0)是\frac{dy}{dt}=f(y),y(t_0)=y_0的解$
#
# $答：\frac{dy_2(t)}{dt}=\frac{dy_1(t-t_0)}{dt}=\frac{dy_1(t-t_0)}{d(t-t_0)}=f(y_1(t-t_0))=f(y_2)$
#
# $所以y_2=y_1(t-t_0)也为\frac{dy}{dt}=f(0)的解$
#
# $y_1(0)=y_0，即t=0时，y_1(0)=y_0$
#
# $所以t-t_0=0时，y_1(t-t_0)=y_0,所以y_2(t_0)=y_0$

# %% [markdown]
# # <font color='red'>A+ 12/9
