# %% [markdown]
# # P27 3.(7)

# %% [markdown]
# $y=x^2+1$
# $y^{\prime}=2x$
#
# going to plug the top two into the follow equation:$y^{\prime}=y^2-(x-1)y+2x$
#
# then coming to :$2x=(x^2+1)^2-(x^2+1)(x^2+1)+2x$
#
# so it solves that equation.

# %% [markdown]
# # 3.(8)

# %% [markdown]
# $y=\frac{-g(x)}{f(x)}$
#
# $y^{\prime}=\frac{(-g(x)^{\prime})f(x)+g(x)(f(x)^{\prime})}{(f(x))^2)}$
#
# going to plug the top two into the follow equation:
# $$
# y{\prime}=\frac{f(x)^{\prime}}{g(x)}y^2-\frac{g(x){\prime}}{f(x)}
# $$
# then coming to :
# $$
# y^{\prime}=\frac{(-g(x)^{\prime})f(x)+g(x)(f(x)^{\prime})}{(f(x))^2)}=\frac{f(x)^{\prime}}{g(x)}(\frac{g(x)^2}{f(x)^2}-\frac{g(x){\prime}}{f(x)}
# $$
#
# so it solves that equation.

# %% [markdown]
# # 4.

# %% [markdown]
# $$\frac{dy}{dx}=2x$$
# (1)
# the solution is $y=x^2+c$
#
# (2)
# substitution$(1,4)$
# then $c=3$
# so the solution is $y=x^2+3$
#
# (3) one intersection,so put $y=x^2+c$into$y=2x+3$
#
# then got:$$x^2-x-3+c=0$$one intersection,so
# solve it got:
# $$c=4$$
# so the solution is  $$y=x^2+4$$
#
# (4)
# $$\int_{0}^{1} (x^2+c)\mathrm{d}x=2$$
# $$(\frac{x^3}{3}+cx)\mid_0^1=2$$
# $$c=\frac{5}{3}$$
# so the solution is:$$y=x^2+\frac{5}{3}$$

# %% [markdown]
# ## (5)
# ### (2)

# %%
var('x')
y(x)=x^2+3
plot(y(x))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## (5)
# ### (3)

# %%
var('x')
y(x)=x^2+4
plot(y(x))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## (5)
# ### (4)

# %%
var('x')
y(x)=x^2+5/3
plot(y(x))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # P42 1.(6)

# %% [markdown]
# $$x\frac{dy}{dx}=y+\sqrt{x^2+y^2}$$
# $\frac{y}{x}=t$,$y=tx$,$$\frac{dy}{dx}=t+x\frac{dt}{dx}$$
# $$arcsint=sgnx ln|x|+c$$
# so $$arcsin\frac{y}{x}=sgnx ln|x|+c$$
# and the other solution is $$|y|=|x|$$

# %% [markdown]
# ## (7)
# $$tan ydx-cot xdy=o$$

# %% [markdown]
# $$ctgydy=tgxdx$$
# so : $$ln|siny|=-ln|cosx|+c$$

# %% [markdown]
# # 2.(6)

# %% [markdown]
# $$\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$$
#  then
#  $$\frac{dy}{dx}=\frac{3[(y^3)^2-2x^2]}{2xy^3+x^2}$$
#
#  $y^3=t$ so.$$\frac{dt}{dx}=\frac{3t^2-6x^2}{2xt+x^2}$$
#
# $\frac{t}{x}=m$ so $$\frac{3m^2-6}{2m+1}=m+x\frac{dm}{dx}=\frac{m^2-m-6}{2m+1}$$
#
# when:$m^2-m-6=0$
#  $$solution:$$
#  $$y^3=3x$$
#  or$$y^3=-2x$$
#  else
#
# $$\frac{2m+1}{m^2-m-6}dm=\frac{1}{x}dx$$
#  then:$$(y^3-3^x)^7(y^3+2x)^3=x^5c$$
#  $solution:$
# $$
# (y^3-3x)^7(y^3+2x)^3=x^{15}c
# $$

# %% [markdown]
# # (7)

# %% [markdown]
# $$\frac{dy}{dx}=\frac{2x^3+3xy+x}{3x^2y+2y^3-y}$$
# $y^2=u$ $x^2=v$
# so:
# $$\frac{du}{dv}=\frac{3u+2v+1}{2u+3v-1}$$
# solve got:$(1,-1)$
# $$z=v-1$$ $$y=u+1$$ $$t=\frac{y}{z}$$
# so:$$\frac{dy}{dz}=\frac{2+3t}{3+2t}$$
# $$z\frac{dt}{dz}=\frac{2-2t^2}{3+2t}$$
# when:$2-2t=0$
#
# $solution$ $$y^2=x^2-2$$or $$y^2=-x^2$$
#
# else:$$y^2=x^2-2 or y^2=-x^2$$
#
# $solution$
# $$y^2+x^2=(y^2-x^2+2)^5c$$

# %% [markdown]
# ## Adding

# %% [markdown]
# $$\frac{dy_2(t)}{dt}=\frac{dy_1(t-t_0)}{dt}=\frac{dy_1(t-t_0)}{d(t-t_0)}$$
# $$f(y_1(t-t_0))=f(y2)$$
# so $y_2=y_1(t-t_0)$also is the solution of $\frac{dy}{dx}=f(x)$
#
# because:$$y_1(0)=y_0$$
# so when $t-t_0=0$ $$y_1(t-t_0)=y(0)$$
# so$$ y_2(t_0)=y_0$$

# %% [markdown]
# # <font color='red'>A 12/9
