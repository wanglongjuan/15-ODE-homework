# %% [markdown]
# 3.(7)因为  $ y=x^2+1 $  所以 $ y^{\prime}=2x $
#
# 所以 $ y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)^2+2x=2x=y^{\prime} $
#
# 因此 $ y=x^2+1 $ 是 $ y^{\prime}=y^2-(x^2+1)y+2x $ 的解

# %% [markdown]
# (8)因为 $ y=-\frac{g(x)}{f(x)} $
#
# 所以 $ y^{\prime}=-\frac{g^{\prime}(x)f(x)-g(x)f^{\prime}(x)}{f^2(x)}=\frac{g(x)f^{\prime}(x)}{f^2(x)}-\frac{g^{\prime}(x)}{f(x)} $
#
# 又 $ \frac{f^{\prime}(x)}{g(x)}y^2-\frac{g^{\prime}(x)}{f(x)}=\frac{f^{\prime}(x)}{g(x)}(-\frac{g(x)}{f(x)})^2-\frac{g^{\prime}(x)}{f(x)}=\frac{g(x)f^{\prime}(x)}{f^2(x)}-\frac{g^{\prime}(x)}{f(x)}=y^{\prime} $
#
# 所以 $ y=-\frac{g(x)}{f(x)} $ 是 $ y^{\prime}=\frac{f^{\prime}(x)}{g(x)}y^2-\frac{g^{\prime}(x)}{f(x)} $ 的解

# %% [markdown]
# 4.(1)由 $ \frac{\mathrm d y}{\mathrm d x}=2x $ ,得 $ \mathrm d y=2x\mathrm d x $ ,方程两边积分，及得 $ y=x^2+c $ ，其中c为任意常数.
#
# 所以，方程 $ \frac{\mathrm d y}{\mathrm d x}=2x $ 的通解为 $ y=x^2+c $ ,c为任意常数.
#
#   (2)把 $ \begin{cases}x=1\\ y=4 \end{cases} $ 代入 $ y=x^2+c $ 得 $ c=3 $ .
#
#   所以 $ y=x^2+3 $ .
#
#   (3)因为相切，所以 $ \begin{cases}y=x^2+c\\y=2x+3 \end{cases} $ 有且只有一解.
#
#   所以 $ c=4 $ .因此 $ y=x^2+4 $ .
#
#   (4)因为 $ \int\limits_0^1  y \mathrm d x= \int\limits_0^1 (x^2+c) \mathrm d x = \left.(\frac{x^3}{3}+cx)\right|_0^1 = \frac{1}{3}+c=2 $
#
#   $ c=\frac{5}{3} $,  所以 $ y=x^2+\frac{5}{3} $.

# %% [markdown]
# (5)画图

# %%
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/2
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 1(6) $ x\frac{\mathrm d y}{\mathrm d x}-y+\sqrt{x^2-y^2}=0 $
#
#  $ x\mathrm d y-y\mathrm d x+\sqrt{x^2-y^2}\mathrm d x=0 $
#
# 当 $ y^2 \neq x^2 $ 时， $ \frac{x\mathrm d y-y\mathrm d x}{\sqrt{x^2-y2}}+\mathrm d x=0 $
#
#    $ \frac{\mathrm d (\frac{y}{x})}{\sqrt{1-(\frac{y}{x})^2}}+\frac{1}{x}\mathrm d x=0 $
#
# 两边积分得 $ \arcsin\frac{y}{x}+\ln{|x|}=c $
#
# 当 $ y^2 = x^2 $ 时，$ y^2 = x^2 $ 也是方程解
#
# 所以，解为 $ y^2 = x^2 $ 和 $ \arcsin\frac{y}{x}+\ln{|x|}=c $

# %% [markdown]
# (7)当 $ \tan{y} \neq 0 $ 时,即 $ y \neq k\pi $,$k=0,\pm{1},\pm{2},\ldots$时
#
#  $ \cot{y}\mathrm dy=\tan{x}\mathrm dx$ ,两边积分 $\ln{|\sin{y}|}=-\ln{|\cos{x}|+c_1}$,即$\sin{y}\cos{x}=c$,其中$c=\pm e^{c_1}$为非零数
#
#  另外,$y=k\pi$,$k=0,\pm{1},\pm{2},\ldots$也是解

# %% [markdown]
# 2.(6)令$u=y^3$,则方程为$\frac{\mathrm du}{\mathrm dx}=\frac{3u^2-6x^2}{2xu+x^2}$
#
# 再令 $v=\frac{u}{x}$ 即 $x\frac{\mathrm dv}{\mathrm dx}+v=\frac{3v^2-6}{2v+1}$
#
# 得 $ \frac{7}{5}\frac{\mathrm dv}{v-3}+\frac{3}{5}\frac{\mathrm dv}{v+2}=\frac{\mathrm dx}{x}$
#
# 两边积分 $ (v-3)^7(v+2)^3=cx^5$
#
# 代回得 $(y^3-3x)^7(y^3+2x)^3=cx^{15}$ 为解

# %% [markdown]
# (7)原方程可化为 $\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# 令$u=x^2-1$,$v=y^2+1$,则方程为$\frac{\mathrm dv}{\mathrm du}=\frac{2u+3v}{3u+2v}$
#
# 再令 $w=\frac{v}{u}$,则$\frac{\mathrm dv}{\mathrm du}=w+u\frac{\mathrm dw}{\mathrm du}$
#
# 所以 $u\frac{\mathrm dw}{\mathrm du}=\frac{2-2w^2}{3+2w}$
#
# 分离变量得 $\frac{4}{u}\mathrm du=(\frac{5}{1-w}+\frac{1}{1+w})\mathrm dw$
#
# 两边积分 $u^4(1-w)^5=c(1+w)$
#
# 代入原式 $(x^2-y^2-2)^5=c(x^2+y^2)$ 为解

# %% [markdown]
# 验证题：
#  $ \frac{\mathrm dy_2(t)}{\mathrm dt}=\frac{\mathrm dy_1(t-t_0)}{\mathrm dt}=\frac{\mathrm dy_1(t-t_0)}{\mathrm d(t-t_0)}=f(y_1(t-t_0))=f(y_2)
#  $
#
#  即 $ y_2=y_1(t-t_0)$也为$\frac{\mathrm dy}{\mathrm dt}=f(y)$的解
#
#  $ t=0 $时, $y_1(0)=y_0$  所以 $t-t_0=0$ 时 $y_1(t-t_0)=y_0$ 即 $y_2(t_0)=y_0$

# %% [markdown]
# # <font color='red'>A+ 12/9
