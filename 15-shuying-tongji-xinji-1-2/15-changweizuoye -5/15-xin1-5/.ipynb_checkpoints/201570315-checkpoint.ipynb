# %%
                                                       计一  唐凯  2015750315

# %% [markdown]
# 1.
# 因为
#
# $$ M = \max{(|x^2 - y^2|)} = 4 $$ ,
#
# 所以
#
# $$ h = \min {(a ,\frac{b}{M})} = \frac{1}{4} $$ ,
#
# 因为 $ y(-1) = 0 $ ,
#
# 所以解的存在区间为
#
# $$ |x - x_0| = |x - (-1)| < \frac{1}{4} $$
#
# 令$\phi_0 (x) = 0$，则有，
#
# $$
# \phi_1(x) = y_0 + \int_{-1}^x x^2 - 0 \mathrm dx = \frac{1}{3}x^3 + \frac{1}{3}
# $$
#
# $$
# \phi_2(x) = y_0 + \int_{-1}^x x^2 - \phi_1(x)^2 \mathrm dx = \frac{1}{3}x^3 - \frac{x}{9} - \frac{x^7}{63} - \frac{x^4}{18} + \frac{11}{42}
# $$
#
# 又因为，
#
# $$
# |\frac{\partial f}{\partial y}| \leq 2 = L
# $$
#
# 则误差估计为，
#
# $$
# |\phi_2 - \phi(x)| \leq \frac{ML^2}{3*2}h^3 = \frac{1}{24}
# $$

# %% [markdown]
# 2.(1).
#
# K > 0时 ，令
#
# $$
# w(t) = K + \int_a^tf(s)g(s) \mathrm ds
# $$
#
# 则有，
#
# $$
# w^\prime(t) = f(t)g(t) \leq g(t)w(t)
# $$
#
# 由 $ w(t) > 0 $可得
#
# $$
# \frac{w^\prime(t)}{w(t)} \leq g(t)
# $$
#
# 两边从 a 到 t 积分得
#
# $$
# \ln w(t) - \ln w(a) \leq \int_a^tg(s) \mathrm ds
# $$
#
# 即有
#
# $$
# \frac{w(t)}{w(a)} \leq \exp(\int_a^tg(s) \mathrm ds) , w(a) = K > 0
# $$
#
# 所以
#
# $$
# w(t) \leq K \exp(\int_a^tg(s)\mathrm ds)
# $$
#
# 即有
#
# $$
# f(t) \leq w(t) \leq K \exp(\int_a^tg(s)\mathrm ds)
# $$
#
# (2).
#
# K = 0 时，对任意 $ \phi > 0 $ , 由于
#
# $$
# f(t) \leq \int_a^tf(s)g(s) \mathrm ds
# $$
#
# 所以
#
# $$
# f(t) \leq \phi + \int_a^tf(s)g(s) \mathrm ds
# $$
#
# 由（1） ， 可得
#
# $$
# f(t) \leq \phi\exp(\int_a^tg(s)\mathrm ds)
# $$
#
# 当 $ \phi \to 0^+ $ 时 ，有$ f(t) \leq 0 $. 又因为 $f(t) \geq 0 $ ,得到 $ f(t) \equiv 0 $，从而
#
# $$
# f(t) \leq K \exp(\int_a^tg(s) \mathrm ds)
# $$
#
# 由（1）（2）知，不等式成立。
#
# 证明：
#
# $ \phi(x) , r(t) $是初值问题 $ x^\prime = f(t ,x) , x(t_0) = x_0 $ 的两个解， 则有
#
# $$
# \phi (t) = x_0 + \int_{t_0}^tf(b ,r(b))\mathrm db , r(t) = x_0 + \int_{t_0}^tf(b ,r(b))\mathrm db
# $$
#
# 于是
#
# $$
# |\phi(t) - r(t)| \leq \int_{t_0}^t|f(b ,\phi(b)) - f(b , r(b))|\mathrm db \leq L\int_{t_0}^t|\phi(b) - r(b)|\mathrm db
# $$
#
# 其中L为利普希茨条件，
#
# 由格朗沃尔不等式知$ K = 0 $ 且
#
# $$
# 0 \leq |\phi(t) - r(t)| \leq K \exp (\int_{t_0}^tL \mathrm db) = 0
# $$
#
# 于是 $ \phi (t) = r(t) $

# %% [markdown]
# 3.
# 设
#
# $$
# M = \max_{\substack{
# x\in[\alpha,\beta] \\
# }}
# \mid f(x ,y_0)\mid
# $$ , $ h = \beta - \alpha , b = M h $, 及有某常数L使得在域 $ R ={(x ,y)|\alpha \leq x \leq \beta , | y - y_0 | \leq b} $ 中有 $ |f(x ,y_1) - f(x ,y_2)|\leq L |y_1 - y_2| ,(x ,y_1) ,(x, y_2) \in R $ .构造逐步逼近函数序列。
#
# $$
# \begin {cases}
# \phi_0 = y_0\\
# \phi_n = y_0 + \int_{x_0}^xf(\eta ,\phi_{n - 1}(\eta)) \mathrm dx , \alpha \leq x \leq \beta , n = 1 , 2,\ldots.
# \end {cases}
# $$
#
# 因
# $$
# |\phi_1(x) - y_0| = |  \int_{x_0}^xf(\eta ,y_0) \mathrm dx| \leq \int_{x_0}^x|f(\eta ,y_0)|\mathrm dx \leq M(x - x_0) \leq M h \leq b .
# $$
#
# 可证
#
# $$
# \phi_n (x) - \phi_{n -1}(x)| \leq \frac{M}{n!}L^{n -1}(\beta -\alpha)^n
# $$
#
# 有，
#
# $$
# | \phi_{n +1} -\phi_n(x) | \leq|\int_{x_0}^x|f(\eta ,\phi_n(\eta)) - f(\eta ,\phi_{n -1})|\mathrm d\eta|
# \leq L|\int_{x_0}^x|\phi_n(\eta) - \phi_{n -1}(\eta)|\mathrm d\eta |\leq L|\int_{x_0}^x\frac{M}{n!}L^{n -1}|\eta - x_0|^n\mathrm d\eta| \leq \frac{M}{(n +1)!}L^n|x -x_0|^{n +1} \leq \frac{M}{(n +1)!}L^n(\beta -\alpha)^{n +1}.
# $$
#
# 由于级数
#
#  $$
#  \sum^\infty_{k=1}\frac{M}{k!}L^{k -1}(\beta -\alpha)^k
#  $$收敛，知级数
#
#  $$
#  \phi_n(x) = \phi_0(x) +\sum^n_{k=1}[\phi_k(x) - \phi_{k -1}(x)]
#  $$
#
#  在区间$ [\alpha,\beta] $一致收敛，于是存在极限
#
#  $$
#  \lim_{n\to\infty}\phi_n(x) = \phi(x)
#  $$,它在区间$ [\alpha ,\beta] $ ,连续 ，且
#
#  $$
#  \phi(x) = \lim_{n\to\infty}\phi_n(x) = y_0 + \lim_{n\to\infty}\int_{x_0}^xf(\eta ,\phi_{n -1}(\eta))\mathrm dx = y_0 +\int_{x_0}^xf(x ,\lim_{n\to\infty}\phi_{n -1}(\eta))\mathrm \eta = y_0 + \int_{x_0}^xf(\eta ,\phi(\eta))\mathrm d\eta
#  $$
#
#  故$ \phi(x) $是积分方程也就是微分方程的解。
#
#  设$ \phi(x) ,\psi(x) $均满足积分方程
#
#  $$
#  y = y_0 + \int_{x_0}^xf(\eta ,y(\eta))\mathrm d\eta ,\alpha \leq x_0 \leq\beta ,\alpha \leq x \leq\beta .
#  $$
#
#  当 $ x\geq x_0$ 时，利用格朗沃尔不等式 ，由
#
#  $$
#  | \phi(x) - \psi(x)| \leq \int_{x_0}^x|f(s ,\phi(s)) -f(s ,\psi (s))| \mathrm ds \leq L\int_{x_0}^x|\phi(s) -\psi(s)|\mathrm ds.
#  $$
#
#  有 $ |\phi(s) - \psi(s)|\leq 0 $ ,即 $ \phi(x) \equiv \psi(x) (\alpha \leq x_0 \leq x \leq \beta) $
#
#  同理可证当$ \alpha \leq x \leq x_0 \beta $ 时有 $ \phi(x) \equiv \psi(x) $ .
#
#  即积分方程也就是微分方程的解是唯一的。

# %% [markdown]
# 4.
# 作逐步逼近函数序列，取 $ \varphi_0 (x) = f(x) $,
#
# 令
#
# $$
# \varphi_1(x) = f(x) + \lambda \int_a^bK(x ,\eta)\varphi_0(\eta) \mathrm d\eta , \ldots
# $$
#
# $$
# \varphi_{n +1} = f(x) + \lambda \int_a^bK(x ,\eta)\varphi_n(\eta)\mathrm d\eta ,\ldots
# $$
#
# 令
#
# $$
# M = \max_{\substack{
# x\in[a ,b]\\
# }}|f(x)| ,
# $$
#
# $$
# L = \max_{\substack{x\in[a ,b]\\
# \eta \in[a ,b]}}|K(x ,\eta)| >0
# $$
#
# 则
#
# $$
# |\varphi_1 (x) - \varphi_0(x)| = |\lambda \int_a^bK(x ,\eta)\varphi_0(\eta) \mathrm d\eta| \leq |\lambda |\int_a^b |K(x ,\eta)||f(\eta)|\mathrm d\eta \leq |\lambda|ML(b -a)
# $$
#
# 假设 $ \varphi_k(x) - \varphi_{k -1}(x)| \leq |\varphi|^k L^k M (b -a)^k $成立，则有
#
# $$
# |\varphi_{k +1}(x) - \varphi_k(x) | = |\lambda \int_a^b K(x ,\eta)(\varphi_k(\eta) - \varphi_{k -1}(\eta) \mathrm d\eta| \leq |\lambda | \int_a^b |K(x ,\eta)|| \varphi_k(\eta) - \varphi_{k -1}(\eta)|\mathrm d\eta \leq |\lambda| \int_a^b L^{k +1} | \lambda |^k M(b -a)^k \mathrm d\eta = |\lambda|^{k +1}L^{k +1} M(b -a)^{ k +1}
# $$
#
# 由数学归纳法知，对任意的 $ n\in N $, 有
#
# $$
# | \varphi_n(x) - \varphi_{n -1}(x)| \leq M L^n(b -a)^n
# $$
#
# 下证 $｛\varphi_n(x)｝$ 在$[a ,b] $ 上一致收敛。
#
# 考虑级数 $ \varphi_0(x) + \sum^\infty_{k =1}(\varphi_k(x) -\varphi_{k -1}(x)) $,只须证该级数在$ [a ,b] $上一致收敛即可。由于
#
# $$
# |\varphi_k(x) - \varphi_{k -1}| \leq M L^k|\lambda |^k(b -a)^k
# $$
#
# 当 $ |\lambda| < \frac{1}{(b -a)L} $ 时，级数 $ \sum^\infty_{k =1}M L^k|\lambda|^k(b -a)^k $ 收 敛， 由此知当 $ |\lambda| <\frac{1}{(b -a)L} $时 ，级 数 $ \varphi_0(x) + \sum^\infty_{k =1}(\varphi_k(x) - \varphi_{k -1}(x)) $在$[a ,b] $ 上一致收敛，即 $ {\varphi_n(x)} $在$ [a ,b] $上一致收敛，不妨设其极限函数为 $ \varphi^*(x) $ ，即当 $ x\in[a ,b] $ 时， $\varphi_n(x) $ 当 $ n\to \infty $ 时一致收敛于 $ \varphi^*(x) $ ,且由 $ \varphi^*(x) $ 的连续性知 $ \varphi^*(x) $ 在 $ [a ,b] $ 上连续 ， 对迭代列，当 $ n\to\infty $ 时两边取极限 ，得
#
# $$
# \varphi^*(x) = f(x) + \lambda \int_a^b K(x , \eta)\varphi^*(\eta) \mathrm d\eta (| \lambda |< \frac{1}{(b -a)L})
# $$
#
# 即当 $ |\lambda | <\frac{1}{(b -a)L} $时 ，积分方程必存在连续解。
#
# 下证当 $| \lambda |<\frac{1}{(b -a)L} $ 时 ，方程的解的唯一性。用反证法。
#
# 设另有解 $ h(x) $ 且 $ h(x) \neq \varphi^*(x) $ ,即 $ h(x) = f(x) + \lambda \int_a^bK(x ,\eta)h(\eta) \mathrm d\eta $
#
# 记 $ M^\prime = \max_{x\in[a ,b]}|\varphi^*(x) - h(x)| >0 $
#
# $$
# | \varphi^*(x) - h(x)| = |\lambda \int_a^bK(x ,\eta)(\varphi^*(\eta) - h(\eta))\mathrm d\eta | \leq |\lambda |\int_a^bL |\varphi^*(\eta) - h(x)|\mathrm d\eta = |\lambda |M^\prime L(b -a)
# $$
#
# 即有$ M^\prime \leq |\lambda| M^\prime L( b -a) $ ,由于 $ M^\prime > 0 $ ,所以, $ |\lambda| \leq \frac{1}{(b -a)L} $，与$ |\lambda|< \frac{1}{(b -a)L}$矛盾。唯一性得证

# %% [markdown]
# # <font color='red'>A  11/10
