# %% [markdown]
# $$P_27第三大题第七小题$$
#
# 因为 $ y = x^2+1 $                       $y^\prime = 2x$
#
#
# 所以$ y^\prime = y^2 - (x^2+1)y +2x=（x^2+1)^2-(x^2+1)(x^2+1)+2x= 2x $
#
#
# 所以 $ y = x^2+1 $ 是 $ y^2\prime = y^2 - (x^2+1)y +2x $ 的解
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# $$P_27第三大题第八小题$$
#
#
#
# 因为 $y = - \frac{g(x)}{f(x)}$
#
#
# 所以 $ y^\prime = - \frac{f(x)g(x)^\prime-f(x)^\prime g(x)}{f(x)^2}= \frac{g(x)f(x)^\prime}{f(x)^2}-\frac{g(x)^\prime}{f(x)}$
#
# 又    $\frac{f(x)^\prime}{g(x)}y^2-\frac{g(x)\prime}{f(x)}=\frac{f(x)^\prime}{g(x)}[-\frac{g(x)}{f(x)}]^2-\frac{g(x)^\prime}{f(x)}$
#
#
# 所以 $ y = -\frac{g(x)}{f(x)} $ 是 $ y = -\frac{f(x)^\prime}{g(x)}y^2-\frac{g(x)^\prime}{f(x)} $ 的解
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# $$P_27第四大题$$
# （1）  微分 $\frac{dy}{dx} = 2x $ 的通解为 $ y = x^2+c$
#
#
#
# (2)  因为 过点 （1，4） 所以 $ y = 1 $ $ x = 4 $ 则 $  c = - 3 $  则  $ y = x^2-3 $
#
#
#
#
# (3)若与直线 $ y = 2x+3 $相切 则有 $ 2x+3 = x^2+c $  此方程有唯一解  所以 $ 4 - 4(c-3) = 0 $ 则  $ c = 3 $ 所以 $ y = x^2+3 $
#
#
#
#
# (4)$ \int_{0}^{1}{ydx} = 2 $ 的 则有 $  \frac{1}{3} + c = 2 $  则 $ c = \frac{5}{3} $ 所以 $ y = x^2 + \frac{5}{3}

# %%
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $$P_42第一大题$$
#
# (6)$ x\frac{\mathrm d y}{\mathrm\ d x}=y +\sqrt{x^2-y^2}　　＃ $
#
# 除 x 有$ \frac{\mathrm d y}{\mathrm\ d x} - \frac{y}{x} + \sqrt{x^2-y^2}=0 $
#
# 是齐次方程  则 令$ u = \frac{y}{x} $
#
# 有 $ y = ux $
#
# $\frac{\mathrm dy}{\mathrm\ dx}=u + x\frac{\mathrm d y}{\mathrm\ d x} $
#
# ＃可化为 $\frac{\mathrm d y}{\mathrm\ d x} - u + \sqrt{1-u^2}=0$
#
# 联立上式得 $x\frac{\mathrm d y}{\mathrm\ d x} = -\sqrt{1-u^2}$
#
# 即 $\frac{\mathrm du}{\sqrt {1-u^2}} = -\frac{\mathrm dx}{x} $
#
# 得  $arcsin\frac{y}{x} + lnx = c$
#
# $另外易知当y^2＝x^2时也是方程的解$
#
#
#
#
#
#
# （7）当$tan x\neq 0$时，即$y\neq k\pi,k=0,\pm 1,\pm 2........时$
#
# 分离变量得$cotydy=tanxdx$.  两边同时积分，得$ln|sin y|=-ln|cos x|+c_1$其中$C_1$为任意常数.
#
# 即$sinycosx=c,$其中$c=e^c$为非零常数.
#
# 另外，$y= k\pi,k=0,\pm 1,\pm 2........$也是方程的解
#
# 所以，原方程的解为$sinycosx=c$及$y=k\pi,k=0,\pm 1,\pm 2........$
#
#
# $$p43第二大题$$
#
#
# （6）令$u=y^2$则方程可变为$\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$,
#
#
# 再令$v= \frac{u}{x}$,即$u=vx$则上面方程化为$x\frac{dv}{dx}+v=\frac{3v^2-6}{2v+1}$,
#
# 整理得 $ \frac{7}{5}\frac{dv}{v-3}+\frac{3}{5}\frac{dv}{v+2}=\frac{dx}{x}$,
#
# 两边同时积分得$ (v-3)^7(v+2)^3=cx^5 $ 其中C为正常数
#
#
#
# （7）原方程可以化为 $ \frac {ydy}{xdx}=\frac{(2x^2+3y^2+1)}{(3x^2+2y^2-1) }$
#
# 令 $ u=x^2-1,v=y^2+1,则原方程可化为\frac{dv}{du}=\frac{(2u+3v)}{(3u+2v) }$
#
# 再令 $ \frac{w=v}{u},即v=uw,则\frac{dv}{du}w+u\frac{dw}{du},从而u\frac{dw}{du}=\frac{(2-2w^2)}{(3+2w)} $
#
# 分离变量化简得 $ \frac{4du}{u}=(\frac{5}{(1-w})+\frac{1}{(1+w)})dw $
#
# 两边积分得 $ u^4(1-w)^5=c(1+w) $
#
# 代回原变量，得到方程的解为 $ (x^2-y^2-2)^5=c(x^2+y^2) $ c为任意常数

# %% [markdown]
# $$黑板上的$$
#
# $$\frac {\mathrm dy_2(t)}{\mathrm dt} = \frac {\mathrm dy_1(t-t_0)}{\mathrm dt}= \frac{\mathrm dy_1(t-t_0)}{\mathrm d(t-t_0)}=f(y_1(t-t_0)) = f(y_2)$$  所以 $$ y_2 = y_1(t-t_0)$$也为  $$ \frac{\mathrm dy}{\mathrm dt} = f(y)$$的解。由 $$y_1(0)= y_0$$得 即$$ t=0$$ 时  $$y_1(0)=y_0$$ 所以$$ t-t_0=0$$时  $$y_1(t-t_0)=y_0$$ 所以 $$ y_2(t_0)=y_0$$ 所以 $$ y_2(t_0)=y_1(t-t_0)$$也是方程的解

# %% [markdown]
# # <font color='red'>A 12/9
