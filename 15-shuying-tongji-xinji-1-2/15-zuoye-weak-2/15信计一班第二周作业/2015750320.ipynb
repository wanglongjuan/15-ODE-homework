# %% [markdown]
# $3(7)$
#
# 因为$y=x^2+1,y^{\prime}=2x$,
#
# 所以$y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x=y^{\prime}$,
#
# 因此，$y=x^2+1$是方程$y^{\prime}=y^2-(x^2+1)y+2x$的解

# %% [markdown]
# $3(8)$
#
# 因为$y=-\frac{g(x)}{f(x)}$,
#
# 所以$y^{\prime}=-\frac{g^{\prime}(x)f(x)-g(x)f^{\prime}(x)}{f^2(x)}=\frac{g(x)f^{\prime}(x)}{f^2(x)}-\frac{g^{\prime}(x)}{f(x)}$
#
# 又$\frac{f^{\prime}(x)y^2}{g(x)}-\frac{g^{\prime}(x)}{f(x)}=\frac{f^{\prime}(x)}{g(x)}(-\frac{g(x)}{f(x)})^2-\frac{g^{\prime}(x)}{f(x)}$
#
# =$\frac{g(x)f^{\prime}(x)}{f^2(x)}-\frac{g^{\prime}(x)}{f(x)}=y^{\prime}$,
#
# 所以，$y=-\frac{g(x)}{f(x)}是方程y^{\prime}=\frac{f^{\prime}(x)y^2}{g(x)}-\frac{g^{\prime}(x)}{f(x)}的解$.

# %% [markdown]
# $4$
# $(1)$
# 微分 $\frac{dy}{dx} = 2x $
#
# 通解为 $ y = x^2+c $

# %% [markdown]
# $(2)$
# 因为过点（1，4） 所以$ x = 1 $ $ y = 4 $
#
# 则 $  c = 3 $  则  $ y = x^2+3 $

# %% [markdown]
# $(3)$
# 若与直线 $ y = 2x+3 $相切 则有 $ 2x+3 = x^2+c $
#
# 此方程有唯一解  所以 $ 4 - 4(c-3) = 0 $ 则  $ c = 4$ 所以$ y = x^2+4 $

# %% [markdown]
# $(4)$
#  $ \int_{0}^{1}{ydx} = 2 $ 的 则有 $  \frac{1}{3} + c = 2 $
#
#  则 $ c = \frac{5}{3} $ 所以 $ y = x^2 + \frac{5}{3} $

# %%
var('x')
f(x)=x^2+3
plot(f(x, -1, 1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x, -1, 1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x, -1, 1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $1(6)$
#
# 原方程化为$xdy-ydx+\sqrt{x^2-y^2}dx=0$.
#
# 当$y^\neq x^2$时,两边同时除以$\sqrt{x^2-y^2}$,
#
# 得$\frac{d(\frac{x}{y})}{\sqrt{1-(\frac{y}{x})^2}}+\frac{1}{x}dx=0$.
#
# 两边积分得到$arcsin{\frac{y}{x}}+In |x|=c$,c为任意常数。
#
# 当$y^2=x^2$时，可以知道这也是一个解。
#
# 所以方程的解为$y^2=x^2$及$arcsin{\frac{y}{x}}+In |x|=c$。

# %% [markdown]
# $1(7)$
#
# 当$tany \neq 0$时，分离变量可得
#
# $cotydy=tanxdx$
#
# 两边同时积分得$In|siny|=-In|cosx|+c_1$,c_1为任意常数，
#
# 即得到$sinycosx=c$,其中$c=\pm e^{c_1}$为非零常数
#
# 所以方程的解为$sinycosx=c,y=k \pi ,k=0,\pm 1,\pm 2，……$

# %% [markdown]
# $2(6)$
#
# 令$u=y^3$
#
# 方程可化为$\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$,
#
# 令$v=\frac{u}{x}$,方程可化为$x\frac{dv}{dx}+v=\frac{3v^2-6}{2v+1}$
#
# 可以化为$7/5\frac{dv}{v-3}+3/5\frac{dv}{v+2}=\frac{dx}{x}$
#
# 积分得到$(v-3)^7(v+2)^3=cx^5$,c为正常数
#
# 方程的解为$(y^3-3x)^7(y^3+2x)^3=cx^{15}$

# %% [markdown]
# $2(7)$
#
# 方程可化为$\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# 令$u=x^2-1$,$v=y^2+1$,方程可化为$\frac{dv}{du}=\frac{2u+3v}{3u}{3u+2v}$
#
# 令$w=\frac{v}{u}$,得$\frac{dv}{du}=w+u\frac{dw}{du}$,$u\frac{dw}{du}=\frac{2-2w^2}{3+2w}$,
#
# 化简得$\frac{4}{u}du=(\frac{5}{1-w}+\frac{1}{1+w})dw$
#
# 积分得$u^4(1-w)^5=c(1+w)$,
#
# 方程的解为$(x^2-y^2-2)^5=c(x^2+y^2)$,c为正常数.

# %% [markdown]
# $3$
#
# $\frac {\mathrm dy_2(t)}{\mathrm dt} = \frac {\mathrm dy_1(t-t_0)}{\mathrm dt}= \frac{\mathrm dy_1(t-t_0)}{\mathrm d(t-t_0)}=f(y_1(t-t_0)) = f(y_2)$
#
# 所以 $ y_2 = y_1(t-t_0)$
#
# 也为  $ \frac{\mathrm dy}{\mathrm dt} = f(y)$的解。
#
# 由 $y_1(0)= y_0$得
#
# 即$ t=0$ 时
#
# $y_1(0)=y_0$
#
# 所以$ t-t_0=0$时  $y_1(t-t_0)=y_0$
#
# 所以 $ y_2(t_0)=y_0$ 所以 $ y_2(t_0)=y_1(t-t_0)$也是方程的解

# %% [markdown]
# # <font color='red'>A+ 12/9
