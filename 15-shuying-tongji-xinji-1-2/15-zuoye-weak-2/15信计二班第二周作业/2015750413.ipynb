# %% [markdown]
# 常微分作业                                --周铁军

# %% [markdown]
# $$一.验证下列各函数是相应微分方程的解$$
# $$(7).y=x^2+1，y'=y^2-(x^2+1)y+2x;$$
# $$证：对y=x^2+1求导得:$$
# $$y'=2x$$
# $$又因为y'=y^2-(x^2+1)y+2x;$$
# $$将y=x^2+1代入得$$
# $$y'=(x^2+1)^2-(x^2-1)(x^2+1)+2x$$
# $$ =2x$$
# $$证毕$$

# %% [markdown]
# $$(8).y=-\frac{g(x)}{f(x)},y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}.$$
# $$证：对y=-\frac{g(x)}{f(x)}求导得：$$
# $$y'=-\frac{g'(x)f(x)-g(x)f'(x)}{f^2(x)}$$
# $$又因为y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}；$$
# $$将y=-\frac{g(x)}{f(x)}代入得：$$
# $$y'=\frac{f'(x)}{g(x)}(y=-\frac{g(x)}{f(x)})^2-\frac{g'(x)}{f(x)}$$
# $$=-\frac{g'(x)f(x)-g(x)f'(x)}{f^2(x)}$$
# $$证毕$$

# %% [markdown]
# $$二.给一阶微分方程\frac{dy}{dx}=2x,$$
# $$(1)求出他的通解。$$
# $$对dy=2xdx求积分得:$$
# $$y=x^2+c$$

# %% [markdown]
# $$(2)求通过点（1,4）的特解；$$
# $$将（1,4）代入通解中得：$$
# $$c=3$$
# $$所以特解为y=x^2+3$$

# %% [markdown]
# $$(3)求出与直线y=2x+3相切的解；$$
# $$联立\begin{cases}
# y=x^2+c\\
# y=2x+3
# \end{cases}$$
# $$解得c=4时，与直线相切$$
# $$所以解为y=x^2+4$$

# %% [markdown]
# $$(4)求出满足条件\int{{y}}dy$$
# $$将y=x^2+c代入得$$
# $$\frac{(1)^3}{3}+c-0=2$$
# $$解得c=\frac{5}{3}$$
# $$即y=x^2+\frac{5}{3}$$

# %% [markdown]
# $$(5)绘出（2）（3）（4）中的解的图形$$

# %%
var('x y')
y=x^2+3
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+4
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+5/3
plot(y,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 三.*求下列方程的解*
# $$（6）   x\frac{dy}{dx}-y+\sqrt{x^2-y^2}=0 $$
# $$解：   \frac{dy}{dx}-\sqrt{1-(y/x)^2}=0$$
#    $$令u=\frac{y}{x}及\frac{dy}{dx}=x\frac{dy}{dx}+u代入$$
#    $$x\frac{du}{dx}+u=u-\sqrt{1-u^2}$$
#    $$\frac{du}{dx}=\frac{-\sqrt{1-u^2}}{x}$$
#    $$\frac{du}{\sqrt{1-u^2}}=\frac{-dx}{x}$$
#    $$arcsin(u)=-ln(x)+c$$
#    $$带回原来变量得$$
#    $$y=xsin(-ln(x)+c)$$

# %% [markdown]
# $$(7) tan(y)dx-cot(x)dy=0$$
# $$解： 当tan(y)不等于0时$$
# $$tan(x)dx-cot(y)dy=0$$
# $$-ln(cos(x))+ln(sin(y))=0$$
# $$cosx=siny$$
# $$y=arcsin(cos(x))$$

# %% [markdown]
# 四.*做适当变量变换求解下列方程：*
# $$(6)\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$$
# $$令u=y^3,化为齐次方程$$
# $$\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$$
# $$再由变换u=tx化为变量分离方程$$
# $$\frac{dx}{x}=(\frac{7}{5(t-3)}+\frac{3}{5(t+2)})dt$$
# $$解得（y^3-3x)^7(y^3+2x)^3=cx^15$$

# %% [markdown]
# $$(7)\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3_y}$$
# $$解：方程可改写为$$
# $$\frac{d(y^2+1)}{d(x^2-1)}=\frac{2(x^2_1)+3(y^2+1）}{3（x^2-1)+2(y^2+1)};$$
# $$取变换\begin{cases}
# t=x^2-1,\\
# s=y^2+1,
# \end{cases}$$
# $$化为齐次方程\frac{ds}{dt}=\frac{2t+3s}{3t+2s}.$$
# $$再令s=wt,得t\frac{dw}{dt}=\frac{2-2w^2}{3+2w},$$
# $$\frac{dt}{t}=\frac{3+2w}{2(1-w^2)}dw$$
# $$=\frac{1}{4}(\frac{5}{1-w}+\frac{1}{1+w})dw;$$
# $$积分得-\frac{5}{4}ln|1-w|+\frac{1}{4}ln|1+w|=ln|t|=c,$$
# $$(1+w)=ct^4(1-w)^5,$$
# $$即t+s=c(t-s)^5,$$
# $$通解为x^2+y^2=c(x^2-y^2-2)^5,其中c为任意数$$

# %% [markdown]
# $$已知y1(t)是\frac{dy}{dt}=f(y),y(0)=y0的解，证y2(t）=y1（t-t0)是\frac{dy}{dt}=f(y),y(t0)=y0的解$$
# $$令k=0$$
# $$即有y1(t-0)是\frac{dy}{dt}=f（y),y(0)=y0的解$$
# $$通解为yn(t)=y1(t-k)是\frac{dy}{dt}=f(y),y(k)=y0的解$$
# $$令k=t0 $$
# $$y2(t）=y1（t-t0)是\frac{dy}{dt}=f(y),y(t0)=y0的解$$

# %% [markdown]
# # <font color='red'>A  12/9
