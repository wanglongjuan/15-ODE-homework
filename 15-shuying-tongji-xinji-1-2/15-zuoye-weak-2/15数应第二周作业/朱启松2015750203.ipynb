# %% [markdown]
#  #               第一次作业        2015750203          朱启松

# %% [markdown]
# ## 3.验证下列各函数是相应微分方程的解：

# %% [markdown]
# $$ （7）$ y=x^2+1,y'=y^2-(x^2+1)y+2x;$$
#
# $$证明：因为 y'=2x,y^2=x^4+2x^2+1=(x^2+1)y$$
#
# $$y^2-(x^2+1)y+2x=2x,y'=2x$$
#
# $$所以y'=y^2-(x^2+1)y+2x $$

# %% [markdown]
# $$ (8)y=-\frac{g(x)}{f(x)},y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)} $$
# $$证明：因为y'=\frac{f'(x)g(x)-g'(x)f(x)}{f^2(x)}$$
# $$y^2=\frac{g^2(x)}{f^2(x)}$$
# $$\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}=\frac{f'(x)g(x)}{f^2(x)}-\frac{g'(x)}{f(x)}=\frac{f'(x)g(x)-g'(x)f(x)}{f^2(x)}$$
# $$所以y'=\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$$

# %% [markdown]
#  ## 4.给定一阶微分方程$ \frac{dy}{dx}=2x$
# ## $（1）求出它的通解$
#
# ## $（2）求通过点（1,4）的特解$
#
# ## $（3）求出与直线y=2x+3相切的解$
#
# ## $（4）求出满足条件\int^1_0ydx=2的解$
# ## $（5）绘出（2），（3），（4）中的解的图形$

# %% [markdown]
# $$ （1）解：dy=2xdx,\int dy=\int 2xdx+c$$
#
# $$      y=x^2+c $$
#
# $$（2）   把（1，4）带入y=x^2+c 得 c=3$$
#
# $$所以y=x^2+3$$
#
# $$（3）\frac{dy}{dx}=2x,直线y=2x+3中dy=2$$
# $$所以x=1，c=4$$
# $$所以解为（1,5）$$
# $$（4）\int^1_0ydx=\int^1_0(x^2+c)dx=\frac{1}{3}x^3+cx=\frac{1}{3}+c=2$$
# $$c=\frac{5}{3}$$

# %%
x=var('x')
plot(x^2+3,(x,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
plot(x^2+4,(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
plot(x^2+5/2,(x,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## 1.求下列方程的解：
# ##  $（6）x\frac{dy}{dx}-y+\sqrt{x^2-y^2}=0;$
# ##  $（7）\tan ydx-\cot xdy=0;$

# %% [markdown]
#  $$ （6）解：两边同时除x $$
#  $$ 得\frac{dy}{dx}=\frac{y}{x}-\frac{ |x|}{x}\sqrt{1-\frac{y^2}{x^2}}$$
#  $$ 令u=\frac{y}{x},y=ux $$
#  $$ x\frac{du}{dx}=-\frac{ |x|}{x}\sqrt{1-u^2}$$
#  $$得当y^2\neq x^2时， arcsin \frac{y}{x}=sgn(x)ln|x|+c ，否则y^2=x^2$$
#
#  $$（7）解：\frac{dy}{cotx}=\frac{dy}{tany}$$
#  $$tanxdx=cotydy$$
#  $$两边同时积分得-ln|cosx|=ln|siny|+c$$
#  $$ sinycosx=c或y=k\pi,k=0,\pm1,...$$

# %% [markdown]
# ## 2.作适当的变量变换求解下列方程

# %% [markdown]
# $（6）\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$
#
# $（7）\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}$

# %% [markdown]
# $$ 解：（6）将方程化简为$\frac{y^2dy}{dx}=\frac{\frac{y^6}{x^2}-2}{2\frac{y^3}{x}+1}$$
#
# $$ 令u=\frac{y^3}{x}可得\frac{dy}{dx}=x\frac{du}{dx}+u$$
#
# $$对变化后的方程分离变量有\frac{2u+1}{u^2-u-6}du=\frac{dx}{x}$$
#
#    $$对两边同时积分可得(u+2)^3(u-3)^7=cx^5$$
#
#    $$将u=\frac{y^3}{x}代入有(\frac{y^3}{x}+2)^3(\frac{y^3}{x}-3)^7=cx^5$$
#
#    $$化简后得到方程的通解为(y^3-3x)^7(y^3+2x)^3=cx^{15}$$

# %% [markdown]
#  解：（7）$$提取公因式得\frac{dy}{dx}=\frac{x(2x^2+3y^2+1)}{y(3x^2+2y^2-1)}$$
#
#   $$即\frac{dy^2}{dx^2}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$$
#
#   $$令a=x^2,b=y^2即有\frac{db}{da}=\frac{2a+3b+1}{3a+2b-1}$$
#
#  $$\begin{cases} 2a+3b+1=0 \\ 3a+2b-1=0\end{cases}解得其交点为(1,-1)$$
#
#    $$令\begin{cases} X=a-1 \\ Y=b+1\end{cases}$$
#
#    $$得\frac{dY}{dX}=\frac{2X+3Y}{3X+2Y}$$
#
#    $$令Y=uX可得\frac{du}{dX}=\frac{\frac{3u+2}{2u+3}-u}{X}$$
#
# $$ 两边同时积分可得 (u-1)^5X^4=c(u+1)$$
#
# $$所以(y^2-x^2+2)^5=c(x^2+y^2)$$

# %% [markdown]
# ##  3.设$ y_1(t)$是$\frac{dy}{dt}=f(y),y(0)=y_0$的解.证明$y_2(t)=y_1(t-t_0)$是$\frac{dy}{dt}=f(y),y(t_0)=y_0$的解.
# $$ 证明：因为y_1(t)是\frac{dy}{dt}=f(y),y(0)=y_0的解.$$
#
# $$所以 y_1(0)=y_0,y_1'(t)=f(y_1(t))$$
#
# $$令t=t_1+c.得y_1'(t_1+c)=f(y_1(t_1+c))$$
#
# $$y_1(t+c)也是方程\frac{dy}{dt}=f(y)的解$$.
#
# $$由题设条件有y(t_0)=y_0,所以y_2(t_0)=y_1(t_0+c)=y_0$$
#
# $$当t_0+c=0等式成立,得c=-t_0$$
#
# $$所以y_2(t)=y_1(t-t_0)是\frac{dy}{dt}=f(y),y(t_0)=y_0的解.$$

# %% [markdown]
# # <font color='red'>A 12/9
