# %% [markdown]
# $数学与应用数学专业 2015750224 赵芙含$

# %% [markdown]
# $3.（7） y'=2X 所以左边=2x$

# %% [markdown]
# $右边=(x^2+1）^2_(X^2+1)(X^2+1)+2X=2X$

# %% [markdown]
# $因为左边=右边 所以此函数是原方程的解$

# %% [markdown]
# $(8)y'=\frac{g(x)f'(x)_f(x)g'(x)}{f^2(x)}$

# %% [markdown]
# $右边=\frac{f'(x)g(x)}{f^2(x))}_\frac{g'(x)}{f(x)}=左边$

# %% [markdown]
# $因为 左边=右边 所以 此函数是原常微分方程的解$

# %% [markdown]
# $4.(1)因为y'=2x 所以y=\int\mathrm{2x}\,\mathrm{d}x=x^2+c$

# %% [markdown]
# $(2)代入点(1,4)进入y=x^2+C中$

# %% [markdown]
# $可以得到C=3 $

# %% [markdown]
# $所以y=x^2+3$

# %% [markdown]
# $(3)  y=2x+3的斜率为2$

# %% [markdown]
# $当原式的斜率为2时 x=1 并代入y=2x+3中 可得y=5$

# %% [markdown]
# $因此点（1，5）在原曲线上面，将点代入 可得C=4$

# %% [markdown]
# $所以 y=x^2+4$

# %% [markdown]
# $(4\int_0^1 \mathrm y\,\mathrm{d}x=\int_0^1 \mathrm({x^2+c})\,\mathrm{d}x=(\frac{x^3}{3}+cx)\mid_0^1=\frac{1}{3}+c=2$)$

# %% [markdown]
# $解得c=\frac{5}{3}    因此y=x^2+\frac{5}{3}$

# %% [markdown]
# $(5)$

# %% [markdown]
# $二题图如下$

# %%
var('t')
f(t) = t^2+3
plot(f,(t,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $三题图$

# %%
var('t')
f(t) = t^2+4
plot(f,(t,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $四题图$

# %%
var('t')
f(t) = t^2+5/3
plot(f,(t,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $P42 1.（6）$

# %% [markdown]
# $两边同时除以x可以得到：\frac{dy}{dx}=\frac{y}{x}-\sqrt{1-(\frac{y}{x})^2}①$

# %% [markdown]
# $以\frac{y}{x}=u及\frac{dy}{dx}=x\frac{du}{dx}+u代入，得到x\frac{du}{dx}+u=u-\sqrt{1-u^2}$

# %% [markdown]
# $化简得:-\frac{du}{\sqrt{1-u^2}}=\frac{dx}{x}+c$

# %% [markdown]
# $两边求积分，得到arcsin\frac{y}{x}+ln|x|=c$

# %% [markdown]
# $由①可得u^2=1也是方程的解，所以原方程的解还有y=±x$

# %% [markdown]
# $(7)$

# %% [markdown]
# $tant y不等于0时 tant xdx=cot ydy,两边求积分得到cos x+sin y=o$

# %% [markdown]
# $tant y=o时，y=nπ，n=……-1，0，1……$

# %% [markdown]
# $令u=y^3,du=3y^2dy,所以\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$

# %% [markdown]
# $令u=tx,代入化简分离方程得\frac{dx}{x}=(\frac{7}{5}\frac{1}{t-3}+\frac{3}{5}\frac{1}{t+2})dt$

# %% [markdown]
# $解得（y^3-3x）^7(y^3+2x)^3=cx^{15}$

# %% [markdown]
# $(7)方程整理得\frac{d(y^2+1)}{d(x^2-1)}=\frac{2(x^2-1)+3(y^2+1)}{3(x^2-1+2(y^2+1)}$

# %% [markdown]
# $令t=x^2-1,s=y^2+1,可以得到\frac{dt}{t}=\frac{2t+3s}{3t+2s}$

# %% [markdown]
# $再令s=wt,得到\frac{dt}{t}=\frac{3+2w}{2(1-w^2)}dw=\frac{1}{4}(\frac(5)(1-w)+\frac{1}{1+w})dw,$

# %% [markdown]
# $积分得到\frac{5}{4}ln|1-w|+\frac{1}{4}ln|1+w|=ln|t|+c,即t+s=(t-s)^5$

# %% [markdown]
# $通解x^2+y^2=c(x^2-y^2-2)^5$

# %% [markdown]
# # <font color='red'>A+  12/9
