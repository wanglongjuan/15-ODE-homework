# %% [markdown]
# ## 常微分方程作业##2015750512
# ## P27 T3(7)##
#
# $y=x^2+1,y'=2x$
#
# $y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)(x^2+1)+2x=2x=y'$
#
# $因此，是方程的解$

# %% [markdown]
# ## （8）##
# $y=\frac{-g(x)}{f(x)},y'=\frac{g'(x)f(x)-f'(x)g(x)}{-f^2(x)}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}$
#
# $又\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}=\frac{f'(x)}{g(x)}(\frac{-g(x)}{f(x)})^2-\frac-{g'(x)}{f(x)}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}=y'$
#
# $所以，得证$

# %% [markdown]
# ## 给定一阶微分方程\frac{dy}{dx}=2x ##
# $（1）、求出它们的通解$
#
# $（2）、求通过点（1，4）的特解$
#
# $（3）、求出与直线y=2x+3相切的解$
#
# $（4）、求出满足条件\int_0^1\mathrm ydx=2的解$
#
# $（5）、绘出2、3、4、中的图形$
#
# $(1)\frac{dy}{dx}=2x.得dy=2xdx，方程两边积分，得到y=x^2+c,c是常数，得到该式主该方程的解$
#
# $(2)将点（1，，4）代入y=x^2+c,得到c=3，可得方程的特解为y=x^2+3$
#
# $(3)因为与直线相切，所以方程y=x^2+c与y=2x+3联立有唯一解，即一元二次方程有唯一解，判别式为0，得到c=4$
#
# $(4)因为\int_0^1\mathrm ydx=\int_0^1\mathrm （x^2+c）dx=\frac{1}{3}+c=2,有c=\frac{5}{3}，得方程的解为y=x^2+\frac{5}{3}$

# %%
var('x y')
y=x^2+3
show(y)
plot(y)
# Out:
# x^2 + 3
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+4
show(y)
plot(y)
# Out:
# x^2 + 4
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
y=x^2+5/3
show(y)
plot(y)
# Out:
# x^2 + 5/3
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# ## P42 T1 (6)(7)##
# $原方程变形为xdy-ydx+(x^2-y^2)^\frac{1}{2}dx=0,当y^2=x^2时，移项，两边同时进行积分可得y^2=x^2是方程的解$
#
# $当y^2不等于x^2时，两边同除以（x^2-y^2）^\frac{1}{2}得到\frac{xdy-ydx}{(x^2+y^2)^\frac{1}{2}}+dx=0$
#
# $即\frac{d(\frac{y}{x})}{(1-(\frac{y}{x})^2)}+\frac{1}{x}dx=0$
#
# $两边进行积分得arcsin\frac{y}{x}+ln|x|=c$
#
# $方程的解为：arcsin\frac{y}{x}+ln|x|=c与y^2=x^2$

# %% [markdown]
# ## 7 ##
# $当y不等于kπ时，分离变量有cotydy=tanxdx，两边同时进行积分，得到ln｜siny｜=-ln｜cosx｜+c1，c1是常数；$
#
# $sinycosx=c是方程的解$
#
# $y=kπ时,k=0,1,-1,2,-2....$
#
# $方程的解为与y=kπ时,k=0,1,-1,2,-2....与sinycosx=c$

# %% [markdown]
# ## P43 T2 (6)(7)##
# $\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$
#
# $令u=y^2,则方程可以变形为\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$
#
# $再令v=\frac{u}{x}，则上面的方程化为\frac{xdv}{dx}+v=\frac{3v^2-6}{2v+1}$
#
# $整理得，\frac{7}{5}\frac{dv}{v-3}+\frac{dv}{v+2}=\frac{dx}{x}$
#
# $两边同时积分得(v-3)^7(v+2)^3=cx^5,c是常数$

# %% [markdown]
# # <font color='red'>结果不对

# %% [markdown]
# ## 7 ##
# $\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}$
#
# $原方程可以化为\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# $令u=x^2-1,v=y^2+1,则方程可以化为\frac{dv}{du}=\frac{2u+3v}{3u+2v}$
#
# $再令w=\frac{v}{u},有\frac{dv}{du}=w+u\frac{dw}{du},从而，u\frac{dw}{du}=\frac{2-2w^2}{3+2w^2}$
#
# $分离变量\frac{4}{u}du=(\frac{5}{1-w}+\frac{1}{1+w})$
#
# $两边积分得$u^4(1-w)^5=c(1+w)$
#
# $代回原变量得原方程的解为（x^2-y^2-2）^5=c(x^2+y^2),c是任意常数$

# %% [markdown]
# ## 设$y_1(t)$是$\frac{du}{dt}=f(y),y(0)=y_0$的解，证明$y_2=y_1(t-t_0)$是$\frac{dy}{dt}=f(y),y(t_0)=y_0)$的解##
# $\frac{dy_2(t)}{dt}=\frac{dy_1(t-t_0)}{d(t-t_0)}=f(y_1(t-t_0))=f(y_2)$
#
# $y_2=y_1(t-t_0)也为\frac{dy}{dt}=f(0)的解$
#
# $y_1(0)=y_0$
#
# $即t=0时y_1(0)=y_0$
#
# $t-t_0=0时,y_1(t-t_0)=y_0$
#
# $所以有y_2(t_0)=y_0$

# %% [markdown]
# # <font color='red'>A  12/9
