# %% [markdown]
# # $$常微分方程<十二>$$
#
# # 姓名：李卓洁
#
# # 学号：2015750116

# %% [markdown]
# ## 5、$设Φ(t)为 方程x'=Ax（A为n*n常数矩阵）的标准基解矩阵（即Φ(0)=E），证明：$
#
# $Φ(t)Φ^{-1}(t_0)=Φ(t-t_0),其中t_0为某一值。$
#
# 解：$根据题意，可得：A是n*n常数矩阵$
#
# $因此，方程x'=Ax的基解矩阵Φ(t)满足：\frac{dΦ(t)}{dt}=AΦ(t)$
#
# 解得：$Φ(t)=e^{At}$即有：$Φ^{-1}(t)=e^{-At}$
#
# 所以：$Φ(t)Φ^{-1}(t_0)=e^{At}e^{-At_0}=e^{A(t-t_0)}=Φ(t-t_0)$

# %% [markdown]
# ## 10.试求下列方程的通解：
#
# $(2)x^{\prime\prime\prime}-8x=e^{2t}$
#
# 解:依题意，齐次方程 $x^{\prime\prime\prime}-8x=0$ 的特征方程为 $$\lambda^3-8=0$$
#
# 解得$\lambda_1=2,\lambda_2=-1+\sqrt 3 i,\lambda_3=-1-\sqrt 3 i$
#
# 所以齐次方程的通解为：$x = C_1e^{2t} + C_2e^{-t}cos\sqrt 3 t + C_3e^{-t}sin\sqrt 3 t$
#
# 这里$f(t)=e^{2t},\lambda=2$
#
# 因为$2$为齐次方程的特征根，所以原方程的特解形如$x = Ate^{2t}$
#
# 代入原方程，解得$(Ate^{2t})^{\prime\prime\prime}-8Ate^{2t}=12Ae^{2t}=e^{2t}$
#
# 所以$A = \frac{1}{12}$
#
# 得特解为$x = \frac{1}{12}te^{2t}$
#
# 从而原方程的通解为
# $x（t）= C_1e^{2t} + C_2e^{-t}cos\sqrt 3 t + C_3e^{-t}sin\sqrt 3 t + \frac{1}{12}te^{2t}$

# %% [markdown]
# ## 11.已知方程组
# $
# \begin{cases}
# \frac{dx_1}{dt}=x_1cos^2 t - x_2(1 - sin t cos t)\\
# \frac{dx_2}{dt}=x_1(1 + sin t cos t) + x_2sin^2 t)
# \end{cases}$
# 有解$x_1= -sin t,x_2 = cos t$，求其通解
#
# 解:设$y_1=\varphi_1(t),y_2=\varphi_2(t)$是方程的满足初值$\varphi_1(0)=1,\varphi_2(0)=0$的一组解
#
# 由第二题的第二问可得，$W^\prime(t)=W(t_0)e^{\int_{t_0}^t [a_{11}(s)+a_{22}(s)+\dots+a_{nn}(s)]\mathrm d s}$
#
# 所以
# $\begin{vmatrix}
# \varphi_1(t) & -\sin t\\
# \varphi_2(t) & \cos t
# \end{vmatrix}
# =
# \begin{vmatrix}
# 1 & 0\\
# 0 & 1
# \end{vmatrix} e^{\int^t_0(\cos^2 t +\sin^2 t)\mathrm d t}=e^t$
#
# 于是$\varphi_1(t)\cos t+\varphi_2(t)\sin t=e^t$
#
# 所以$\varphi_2(t)=\frac{e^t-\varphi_1(t)\cos t}{\sin t}$
#
# 代入方程组的第一个方程得
# $\varphi^{\prime}_1(t)=\varphi_1(t)\cot t+e^t(\cos t-\csc t)$
#
# 这是一个一阶线性微分方程,有
# $
# \begin{aligned}
# \varphi_1(t)&=e^{\int \cot t\mathrm d t}[\int e^s(\cos s - \csc s)\csc s \mathrm ds+c]\\&=\sin t [\int \mathrm d（e^t\cot t)+c]\\&=e^t\cos t+c\sin t
# \end{aligned}
# $
#
# 又由初值条件$\varphi_1(0)=1$,所以$c=0$
#
# 因此$\varphi_1(t)=e^t\cos t,\varphi_2(t)=e^t\sin t$
#
# 综上所述，方程的通解为
# $x_1=-c_1\sin t+c_2e^t\cos t,x_2=c_1\cos t+c_2e^t\sin t$,其中$c_1,c_2$为任意常数

# %% [markdown]
# ## 1.假设A是$n×n$矩阵，试证：
#
#  (2)对任意的常数k,都有$(\exp \mathbf A)^t=\exp k\mathbf A$,$(当k是负整数时，规定(\exp \mathbf A)^k=[(\exp \mathbf A)^{-1}]^{-k}.)$
#
# 解:
#
# 1>当k为非负整数时，用数学归纳法：
#
# 当$k=1$时，显然等式成立
#
# 假设当$k=n-1$时成立，即$$(\exp A)^{n-1}=\exp (n-1)A$$
#
# 当$k=n$时
#
# $
# \begin{aligned}
# 左边&=（\exp A）^n\\&=(\exp A)^{n-1}(\exp A)\\&=\exp (n-1）A\exp A\\&=\exp nA\\&=右边
# \end{aligned}
# $
#
# 所以，对$k=n$也成立
#
# 因此，对任意的非负常数k,都有$(\exp A)^t=\exp kA$
#
# 2>当k为负整数时
#
# $(\exp \mathbf A)^k=[(\exp \mathbf A)^{-1}]^{-k}=[\exp (-\mathbf A)]^{-k}=\exp (-k)(-\mathbf A)=\exp k\mathbf A$
#
# 证毕

# %% [markdown]
# ## 5.试求方程组$x^{\prime}=\mathbf{A}x$的基解矩阵，求满足初值条件$\varphi(0)=\eta$的解$\varphi(t)$：
#
# (2)$\mathbf{A}=
# \begin{bmatrix}
# 1 & 0 & 3\\
# 8 & 1 & -1\\
# 5 & 1 & -1
# \end{bmatrix},
# \eta=
# \begin{bmatrix}
# 0\\
# -2\\
# -7
# \end{bmatrix}$
#
# 解:矩阵的特征方程为
#
# $\det (\lambda \mathbf E-\mathbf A)=
# \begin{vmatrix}
# \lambda-1 & 0 & -3\\
# -8 & \lambda-1 & 1\\
# -5 & -1 & \lambda+1\\
# \end{vmatrix}
# =\lambda^3-\lambda^2-15\lambda-9=0$
#
# 特征值为$\lambda_1=-3,\lambda_{2,3}=2±\sqrt 7$
#
# $\lambda_1=-3$的特征向量$u=\begin{bmatrix} u_1\\u_2\\u_3\\ \end{bmatrix}$满足
#
# $
# \begin{aligned}
# (\lambda_1 \mathbf E-\mathbf A)u&=
# \begin{vmatrix}
# -4 & 0 & -3\\
# -8 & -4 & 1\\
# -5 & -1 & -2\\
# \end{vmatrix}
# \begin{bmatrix} u_1\\u_2\\u_3\\ \end{bmatrix}\\&=
# \begin{vmatrix}
# -4u_1-3u_3\\
# -8u_1-4u_2+u_3\\
# -5u_1-u_2-2u_3\\
# \end{vmatrix}\\&=0
# \end{aligned}
# $
#
# 即$u=\alpha [-3,7,4]^T$,其中$\alpha≠0$为任意常数
#
# 同理可得
#
# $\lambda_2=2+\sqrt 7$的特征向量$v=\beta[3,-5+4\sqrt 7,1+\sqrt 7]^T$
#
# $\lambda_3=2-\sqrt 7$的特征向量$r=\mu[3,-5-4\sqrt 7,1-\sqrt 7]^T$
#
# 所以方程组$x^\prime=\mathbf A$的一个基解矩阵为
#
# $
# \phi(t)=
# \begin{bmatrix}
# -3e^{-3t} & 3e^{(2+\sqrt 7)t} & 3e^{(2-\sqrt 7)t}\\
# 7e^{-3t} & (-5+4\sqrt 7)e^{(2+\sqrt 7)t} & (-5-4\sqrt 7)e^{(2-\sqrt 7)t}\\
# 4e^{-3t} & (1+\sqrt 7)e^{(2-\sqrt 7)t} & (1-\sqrt 7)e^{(2-\sqrt 7)t}\\
# \end{bmatrix}
# $
#
# 因为
# $
# \begin{aligned}
# \mathbf \phi^{-1}(0)&=
# \frac{-1}{108\sqrt 7}
# \begin{bmatrix}
# 18\sqrt 7 & 6\sqrt 7& -24\sqrt 7\\
# -27-9\sqrt 7 & -15+3\sqrt 7 & 6-12\sqrt 7\\
# 27-9\sqrt 7 & 15+3\sqrt 7 & -6-12\sqrt 7\\
# \end{bmatrix}\\&=
# \begin{bmatrix}
# -\frac{1}{6} & -\frac{1}{18} & \frac{2}{9}\\
# \frac{3+\sqrt 7}{12\sqrt 7} & \frac{5-\sqrt 7}{36\sqrt 7} & \frac{-1+2\sqrt 7}{18\sqrt 7}\\
# \frac{-3+\sqrt 7}{12\sqrt 7} & \frac{-5-\sqrt 7}{36\sqrt 7} & \frac{1+2\sqrt 7}{18\sqrt 7}\\
# \end{bmatrix}
# \end{aligned}
# $
#
# 所以满足初值条件$\varphi(0)=\eta$的解为
# $
# \begin{aligned}
# \varphi(t)&=[\exp( \mathbf A t)]\eta\\&=\mathbf \phi(0)\mathbf \phi^{-1}(0)\eta\\&=
# \begin{bmatrix}
# -3e^{-3t} & 3e^{(2+\sqrt 7)t} & 3e^{(2-\sqrt 7)t}\\
# 7e^{-3t} & (-5+4\sqrt 7)e^{(2+\sqrt 7)t} & (-5-4\sqrt 7)e^{(2-\sqrt 7)t}\\
# 4e^{-3t} & (1+\sqrt 7)e^{(2-\sqrt 7)t} & (1-\sqrt 7)e^{(2-\sqrt 7)t}\\
# \end{bmatrix}
# \begin{bmatrix}
# -\frac{1}{6} & -\frac{1}{18} & \frac{2}{9}\\
# \frac{3+\sqrt 7}{12\sqrt 7} & \frac{5-\sqrt 7}{36\sqrt 7} & \frac{-1+2\sqrt 7}{18\sqrt 7}\\
# \frac{-3+\sqrt 7}{12\sqrt 7} & \frac{-5-\sqrt 7}{36\sqrt 7} & \frac{1+2\sqrt 7}{18\sqrt 7}\\
# \end{bmatrix}
# \begin{bmatrix}
# 0\\-2\\-7\\
# \end{bmatrix}\\&=
# \begin{bmatrix}
# \frac{13}{3}e^{-3t}+\frac{2-13\sqrt 7}{6\sqrt 7}e^{(2+\sqrt 7)t}+\frac{-2-13\sqrt 7}{6\sqrt 7}e^{(2-\sqrt 7)t}\\
# -\frac{91}{9}e^{-3t}+\frac{-374+73\sqrt 7}{18\sqrt 7}e^{(2+\sqrt 7)t}+\frac{374+73\sqrt 7}{18\sqrt 7}e^{(2-\sqrt 7)t}\\
# -\frac{52}{9}e^{-3t}+\frac{-89-11\sqrt 7}{18\sqrt 7}e^{(2+\sqrt 7)t}+\frac{89-11sqrt 7}{18\sqrt 7}e^{(2+\sqrt 7)t}\\
# \end{bmatrix}
# \end{aligned}
# $

# %% [markdown]
# # <font color='red'>A 9/12
