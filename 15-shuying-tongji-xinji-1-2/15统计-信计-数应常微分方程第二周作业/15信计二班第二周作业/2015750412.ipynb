# %% [markdown]
# $3.(7)$
#
# $y'=2x$
#
# $y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)^2+2x=2x$
#
# $两边相等$

# %% [markdown]
# $3.(8)$
#
# $y'=-\frac{g'(x)f(x)-g(x)f'(x)}{f^2(x)}$
#
# $\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}=\frac{f'(x)g(x)-g'(x)f(x)}{f^2(x)}$
#
#
# $两边相等$

# %% [markdown]
# $4(1)$
#
# $\int dy=\int 2xdx=x^2+c$
#
# $c为任意常数$

# %% [markdown]
# $4.（2）$
#
# $把x=1,y=4代入y=x^2+c$
#
# $解得c=3$
#
# $特解为$y=x^2+3$

# %% [markdown]
# $4.（3）$
#
# $令x^2+c=2x+3$
#
# $即x^2-2x+c-3=0有唯一解$
#
# $解得c=4$
#
# $所以解是y=x^2+4$

# %%
var('x')

g(x)=x^2+3

plot(g(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')

g(x)=x^2+1

plot(g(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')

g(x)=x^2+3/5

plot(g(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $1.（6）$
#
# $xdy-ydx+\sqrt{x^2-y^2}dx=0$
#
# $1$
#
# $当x^2不等于y^2时$
#
# $\frac{xdy-ydx}{\sqrt{x^2-y^2}}+dx=0$
#
# $分子分母同乘1/x$
#
# $得\arcsin{\frac{y}{x}}+\ln{|x|}=c (c为任意常数)$
#
# $2$
#
# $当$x^2=y^2$时，可证解相同$

# %% [markdown]
# $1.(7)$
#
# $1$
#
# $当$tan{y}$不等于0时$
#
# $\cot{y}dy=\tan{x}dx$
#
# $得\sin{y}\cos{x}=c$
#
# $2$
#
# $当y=k\pi$ k为任意整数,可证解相同$

# %% [markdown]
# $2.（6）$
#
# $令u=y^3,v=\frac{u}{x}$
#
# $x\frac{dv}{dx}+v=\frac{3v^2-6}{2v+1}$
#
# $7(\frac{dv}{v-3})+3(\frac{dv}{v+2})=5\frac{dx}{x}$
#
# $解得(y^3-3x)^7(y^3+2x)^3=cx^15$
#
# $其中c取任意整数$

# %% [markdown]
# $2.（7）$
#
# $\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# $其中令u=x^2-1,v=y^2+1$
#
# $\frac{dv}{du}=\frac{2+3w}{3+2w}$-w
#
# $\frac{(1+w)}{u^4}=(1-w)^5$
#
# $解得c(x^2+y^2)=y^2-x^2+2$
#
# $其中c取任意常数$

# %% [markdown]
# $证明题$
#
# $\frac{dy_2(t)}{dt}=\frac{dy_1(t-t_0)}{d(t-t_0)}=f(y_2(t))$
#
# $y_2(t)=y_1(t-t_0)$
#
# $所以y_2(t_0)=y_1(0)=y_0$
#
# 所以解为$y_2(t)=y_1(t-t_0)$

# %% [markdown]
# # <font color='red'>B  12/9过程太简单
