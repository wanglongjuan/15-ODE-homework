# %% [markdown]
# 3.（7）$y=x^2+1$ ，$y'=y^2-(x^2+1)y+2x$
#
# 解：将 $y=x^2+1$代入第二个方程的右边，即：$y^2-(x^2+1)y+2x$
#
# 可得$y'=2x$
#
# 因为$y=x^2+1$
#
# 所以$y'=2x$
#
# 两边一致
#
# 证毕

# %% [markdown]
# 3.（8）$y=-\frac{g(x)}{f(x)}$,$\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$
#
# 解：将$y=-\frac{g(x)}{f(x)}$代入$\frac{f'(x)}{g(x)}y^2-\frac{g'(x)}{f(x)}$
#
# 得到$\frac{g(x)f'(x)-g'(x)f(x)}{f(x)^2}$
#
# 又因为$y=-\frac{g(x)}{f(x)}$求导得$\frac{g(x)f'(x)-g'(x)f(x)}{f(x)^2}$
#
# 两边一致
#
# 证毕

# %% [markdown]
# 4.$\frac{dy}{dx}=2x$
#
# 解：(1)因为$\frac{dy}{dx}=2x$
#
# 所以$dy=2xd(x)$
#
# 所以$\int dy=\int 2xd(x)$
#
# 所以$y=x^2+c$ , 即为通解
#
#
# (2)设 $f(x)=x^2+c_2$
#
# 将（1,4）代入函数
#
# 得到$4=1+c_2$
#
# 所以$c_2=3$
#
# 特解为$y=x^2+3$
#
#
# (3)设$f(x)=x^2+c_3$
#
# 因为$f'(x)=2x$ , 令$f'(x)=2$
#
# 所以$x=1$,由直线方程$y=2x+3$求出y值为5
#
# 因为该切点既在直线上又在曲线上
#
# 所以令$x^2+c_4=5$
#
# 得到$c_3=4$
#
# 解为$f(x)=x^2+4$
#
# (4)设$f(x)=x^2+c_4$
#
# $\int^1_0(x^2+c_4) dx=(\left.\frac{1}{3}x^3+c_4x)\right|^1_0=\frac{1}{3}+c_4=2$
#
# 所以$c_4=\frac{5}{3}$
#
# 解为$f(x)=x^2+\frac{5}{3}$

# %%
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 1.（6）$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}$
#
# 解：$令\frac{y}{x}=u,y=ux,\frac{dy}{dx}=u+x\frac{du}{dx},则原方程化为：$
#
#    $\frac{du}{dx}=\frac{\sqrt{x^2(1-u^2)}}{x}，分离变量得：\frac{1}{1-u^2}du=sgn x \frac{1}{x}dx$
#
#    $两边积分得：\arcsin u =sgn x \ln |x|+c$
#
#    $代回原来变量，得\arcsin \frac{y}{x}=sgn x \ln |x|+c $
#
#    $另外，y^2=x^2也是方程的解$
#
# 1.（7）$\tan y dx-\cot x dy=0$
#
# 解：变量分离得$\frac{dy}{\tan y}=\tan x dx$
#
#    两边积分得：$\ln |\sin y|=-\ln |\cos x|+c$

# %% [markdown]
# 2.（6）$\frac{dy}{dx}=\frac{y^6-2x^2}{2xy^5+x^2y^2}$
#
# 解：$\frac{dy}{dx}=\frac{(y^3)^2-2x^2}{y^2(2xy^3)+x^2}=\frac{dy^3}{x}=\frac{3[(y^3)^2-2x^2]}{2xy^3+x^2},令y^3=u,则原方程化为$<b2xur>
#
#
#    $\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}=\frac{\frac{3u^2}{x^2}-6}{2\frac{u}{x}+1},这是齐次方程，令$
#
#    $\frac{u}{x}=z,则\frac{du}{dx}=z+x\frac{du}{dx},所以\frac{3z^2-6}{2z+1}=z+x\frac{dz}{dx},x\frac{dz}{dx}=\frac{z^2-z-6}{2z+1}$
#
#    $当z^2-z-6=0,得z=3或z=-2,所以y^3=3x或y^3=-2是方程的解$
#
#    $当z^2-z-6\neq 0,变量分离\frac{2z+1}{z^2-z-6}dz=\frac{1}{x}dx，两边积分$
#
#    $(y^3-3x)^7(y^3+2x)^3=x^5c,又因为y^3=3x或y^3=-2x包含在通解中当c=0时，故原方程的解为(y^3-3x)^7(y^3+2x)^3=x^5c$
#
# （7）$\frac{dy}{dx}=\frac{2x^3+3xy^2+x}{3x^2y+2y^3-y}$
#
# 解：$原方程化为\frac{dy}{dx}=\frac{x(2x^2+3y^2+1)}{y(3x^2+2y^2-1)},\frac{dy^2}{dx^2}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
#    $令y^2=u,x^2=v,则\frac{du}{dv}=\frac{2v+3u+1}{3v+2u-1}$
#
#    $方程组\left\{\begin{array}\\2v+3u+1\\{3v+2u-1} \end{array}\right.的解为（1,-1），令q=v-1,p=u+1$
#
#    $则有\left\{\begin{array}\\2q+3p=0\\{3q+2p=0} \end{array}\right.可得\frac{dp}{dq}=\frac{2+3\frac{p}{q}}{3+2\frac{p}{q}}$
#
#    $令t=\frac{p}{q},则有\frac{dp}{dq}=t+z\frac{dp}{dq},所以t+q\frac{dt}{dq}=\frac{2+3t}{3+2t},q\frac{dt}{dq}=\frac{2-2t^2}{3+2t}$
#
#    $当2-2t^2=0,即t=\pm ,得y^2=x^2-2或y^2=-x^2是原方程的解$
#
#    $当2-2t^2\neq 0时，分离变量得\frac{3+2t}{2-2t^2}dt=\frac{1}{q}dq两边积分得y^2+x^2=(y^2-x^2+2)^5c$
#
#    $另外，y^2=x^2-2或y^2=-x^2,包含在其通解中，故原方程的解为y^2+x^2=(y^2-x^2+2)^5c$

# %% [markdown]
# 证明：设$y_1(t)$是$\frac{dy}{dt}=f(y),y(0)=y_0$的解
#
# 则$y_2(t)=y_1(t-t_0)是\frac{dy}{dt}=f(y),y(t_0)=y_0$的解
#
# $f(y_2(t))=f(y_1(t-t_0)=\frac{dy_1(t-t_0)}{dt}=\frac{dy_2}{dt}$
#
# $y_2(t_0)=y_1(0)=y_0$

# %% [markdown]
# # <font color='red'>A  12/9
