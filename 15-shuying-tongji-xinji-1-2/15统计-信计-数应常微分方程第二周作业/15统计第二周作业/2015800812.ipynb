# %% [markdown]
# 常微分方程第一次作业
# 27页
# 第三题（7）
#
# $ 右式=y^2-（x^2+1）y+2x=(x^2+1)^2-(x^2+1)^2+2x=2x $
#
# $ 左式=y'=2x $
#
# 左式等于右式
#
# 故该函数是微分方程的解。

# %% [markdown]
# (8)
#
# $y=-\frac{g(x)}{f(x)}$
#
# $左式=\frac{f'(x)g(x)-g'(x)f(x)}{f^2(x)}$
#
# $右式=\frac{f'(x)*y^2}{g(x)}-\frac{g'(x)}{f(x)}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}=\frac{f'(x)g(x)-g'(x)f(x)}{f^2(x)}$
#
# 左式等于右式
#
# 故该函数是微分方程的解。

# %% [markdown]
# 第四题
#
# （1）
# 因为$\frac{dy}{dx}$
#
# 故$dy=2xdx$
#
# 两边同时积分
#
# 得$y=x^2+C$ C为任意常数。
#
# （2）
# 把x=1,y=4代入$y=x^2+C$,解得C=3
#
# 故特解是$y=x^2+3$
#
# (3)
# 因为相切，故两个方程联立，只有唯一一组解。
#
# 即$x^2+C=2x+3$有唯一解，所以C=4
#
# 故与直线y=2x+3相切的解是$y=x^2+4$
#
# (4)$\int^1_0{y}{dx}=\int^1_0{x^2+C}{dx}=[x^3/3+Cx]^1_0=1/3+C=2$
#
# 解得C=5/3
#
# 故特解是$y=x^2+5/3$

# %%
(5)
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# 四十二页
# 第一题
# (6)因为$x\frac{dy}{dx}-y+\sqrt{x^2-y^2}=0$
#
# 则$xdy-ydx+\sqrt{x^2-y^2}dx=0$
#
# 当x^2不等于y^2时，
#
# $\frac{xdy-ydx}{\sqrt{x^2-y^2}}+dx=0$
#
# 即$\frac{d(\frac{y}{x})}{\sqrt{1-(\frac{y}{x})^2}}+\frac{1}{x}dx=0$
#
# 两边积分得 $arcsin{\frac{y}{x}}+\ln{|x|}=c$
#
# 其中c为任意常数
#
# 而当$x^2=y^2$时，其也是方程的解。
#
# 故原方程的解为 $arcsin{\frac{y}{x}}+\ln{|x|}=c$ 或$x^2=y^2$

# %% [markdown]
# （7）当$\tan{y}$不为0时，即y不等于$k\pi$, 其中，k是任意整数
#
# $\cot{y}dy=\tan{x}dx$
#
# 两边同时积分，得
#
# $\ln{|\sin{y}|}=-\ln{|\cos{x}|}+c_1$
#
# 其中，$c_1$是任意常数。
#
# 故$\sin{y}\cos{x}=c$
#
# 当y等于$k\pi$， 其中k是任意整数时，也是方程的解。
#
# 综上，方程的解是$\sin{y}\cos{x}=c$  或y等于$k\pi$， 其中，k是任意整数。

# %% [markdown]
# 第二题
# （6）
# 令$u=y^3$
#
# 方程变形为
#
# $\frac{du}{dx}=\frac{3u^2-6x^2}{2xu+x^2}$
#
# 令$v=\frac{u}{x}$,即$u=vx$
#
# 则方程进一步化简可得
#
# $x\frac{dv}{dx}+v=\frac{3v^2-6}{2v+1}$
#
# 整理得$\frac{7}{5}*\frac{dv}{v-3}+\frac{3}{5}*\frac{dv}{v+2}=\frac{dx}{x}$
#
# 两边同时积分得$(v-3)^7(v+2)^3=cx^5$    其中c为常数
#
# 代入$v=\frac{u}{x}=\frac{y^3}{x}$,化简可得
#
# $(y^3-3x)^7(y^3+2x)^3=cx^15$

# %% [markdown]
# (7)
# 化简原方程得
#
# $\frac{ydy}{xdx}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# 即$\frac{dy^2}{dx^2}=\frac{2x^2+3y^2+1}{3x^2+2y^2-1}$
#
# 令$u=x^2-1$,$v=y^2+1$,则方程化简为
#
# $\frac{dv}{du}=\frac{2u+3v}{3u+2v}$
#
# 再令$w=\frac{v}{u}$
#
# 得 $u\frac{dw}{du}+w=\frac{2+3w}{3+2w}$
#
# 分离变量积分得               $c(1+w)=u^4(1-w)^5$
#
# 代入未知数得                 $c(x^2+y^2)=（y^2-x^2+2）^5$           c为任意常数

# %% [markdown]
# 附加题
#
# 因为$\frac{dy_2(t)}{dt}=\frac{dy_1(t-t_0)}{d(t-t_0)}=f(y_1(t-t_0))=f(y_2(t))$
#
# 故$y_2(t)=y_1(t-t_0)$是$\frac{dy}{dt}=f(y)$的解
#
# 而$y_2(t_0)=y_1(t_0-t_0)=y_1(0)=y_0$
#
# 故$y_2(t)=y_1(t-t_0$是$y(t_0)=y_0$的解

# %% [markdown]
# # <font color='red'>A+  12/9
