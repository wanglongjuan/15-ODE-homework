# %% [markdown]
#                                          9月10日
#                                       谭治港 2015750502
# $P37T3(7)$
#
# $y'=2x$
#
# $y^2-(x^2+1)y+2x=(x^2+1)^2-(x^2+1)^2+2x=2x=y'$
#
# $所以y=x^2+1是该方程的解$

# %% [markdown]
# $(8)$
#
# $因为y'=\frac{g'(x)f(x)-g(x)f'(X)}{f^2(x)}$
#
# $而\frac{f'(x)y^2}{g(x)}-\frac{g'(x)}{f(x)}=\frac{g(x)f'(x)}{f^2(x)}-\frac{g'(x)}{f(x)}=y'$
#
# $所以是该方程的解$

# %% [markdown]
# $T4(1)$
#
# $\frac{dy}{dx}=2x，有dy=2xdx$
#
# $方程两边同时积分，即得y=x^2+c,c为常数$
#
# $所以，方程\frac{dy}{dx}=2x的通解为y=x^2+c,c为任意常数$

# %% [markdown]
# $(2)$
#
# $把点（1，4）代入y=x^2+c得c=3$
#
# $所以过点（1，4）的特解为y=x^2+3$

# %% [markdown]
# $(3）$
#
# $方程组有且只有唯一解，即x^2=2x+3有唯一解$
#
# $因此c=4$
#
# $即与直线y=2x+3相切的解是y=x^2+4$

# %% [markdown]
# $(4)$
#
# $因为c=\frac{5}{3}$
#
# $所以，y=x^2+\frac{5}{3}$

# %%
var('x')
f(x)=x^2+3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+4
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x')
f(x)=x^2+5/3
plot(f(x,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# $P42T7(6)$
#
# $xdy-ydx+\sqrt{x^2-y^2}dx=0$
#
# $当x^2不等于y^2时，两边同除以\sqrt{x^2-y^2}得\frac{（xdy-ydx）}{\sqrt{x^2-y^2}}+dx=0$
#
# $即\frac{d(\frac{y}{x})}{\sqrt{1-(y/x)^2}}+(1/x)dx=0$
#
# $两边积分得arcsin(\frac{y}{x})+ln|x|=c,c为任意常数$
#
# $当y^2=x^2时，易验证y^2=x^2也是方程的解$
#
# $即原方程的解为y^2=x^2及arcsin(\frac{y}{x})+ln|x|=c$

# %% [markdown]
# $(7)$
#
# $tan y不为0时，即y不等于kπ，k=……-2，-1，0，1，2，……时，分离变量得cot ydy=tan xdx$
#
# $ln|sin y|=-ln|cos x|+C1,C1为任意常数$，即sin ycos x=C,其中C=+(-)e^C1为非零常数$
#
# $另外，y=kπ，k=……-2，-1，0，1，2，……也是方程的解$
#
# $从而原方程的解为sin ycos x=C及y=kπ，k=……-2，-1，0，1，2，……$

# %% [markdown]
# $P42T2(6)$
#
# $令u=y^2,为\frac{du}{dx}=\frac{（3u^2-6x^2）}{(2xu+x^2)}$
#
#  $再令v=\frac{u}{x},\frac{xdv}{dx}+v=\frac{(3v^2-6)}{(2v+1)},\frac{(\frac{7}{5})dv}{(v-3)}+\frac{(\frac{3}{5})dv}{(v+2)}=\frac{dx}{x}$
#
#  $两边同时积分，得（v-3）^7(v+2)^3=cx^5,c为正常数$
#
#  $化简得（y^3-3x）^7(y^3+2x)^3=c(x)^15 $

# %% [markdown]
# $(7)$
#
# $变形为\frac{ydy}{xdx}=\frac{（2x^2+3y^2+1）}{(3x^2+2y^2-1)}$
#
# $令u=x^2-1,v=y^2+1,则方程可以化为\frac{dv}{du}=\frac{（2u+3v）}{（3u+2v）}$
#
# $再令w=\frac{v}{u}，则有\frac{dv}{du}=w+\frac{udw}{du},化简得\frac{4du}{u}=[{\frac{5}{(1-w)}}+{\frac{1}{(1+w)}}]dw$
#
# $两边积分得u^4(1-w)^5=c(1+w)$
#
# $即原方程的解为（x^2-y^2-2）^5=c(x^2+y^2),c为任意常数$

# %% [markdown]
#               $证明题$
#
# $证明：因为\frac{dy2（t）}{dt}=\frac{dy1（t-t0）}{d（t）}=f[y1(t-t0)]=f(y2)$
#
# $所以y2=y1(t-t0)也为\frac{dy}{dt}=f（y）的解$
#
# $由y1(0)=y0得t=0时，y1（0）=y0$
#
# $所以，t-t0=0时，y1（t-t0）=y0.即y2（t0）=y0$

# %% [markdown]
# # <font color='red'>A+  12/9
