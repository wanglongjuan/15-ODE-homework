# %% [markdown]
# $2015750407魏雄峰常微分第十二周作业$

# %% [markdown]
# $P183\quad1.$

# %% [markdown]
# $(2)解：方程不显含t，令y=x',则有xy\frac{dy}{dx}-y^2+y^3=0,$
#
# $\therefore y=0,或者\frac{dy}{dx}=\frac{y-y^2}{x}$
#
# $积分后得\frac{y}{1-y}=c_1x(c\neq 0)即y=\frac{c_1x}{1+c_1x},\therefore x'=\frac{c_1x}{1+c_1x}$
#
# $积分后得x+\frac{1}{c_1} \ln |x|=t+c_2,即方程有解x+\frac{1}{c_1} \ln |x|=t+c_2,当y=0时得x'=0或x=c$
#
# $综上，方程的解为x+\frac{1}{c_1} \ln |x|=t+c_2或x=c(c_1,c_2,c为任意常数)$

# %% [markdown]
# $(4)解：方程不显含t，令y=x',则有y\frac{dy}{dx}+\sqrt{1-y^2}=0$
#
# $当y \neq \pm 1,方程可变形为\frac{ydy}{\sqrt{1-y^2}}=-dx,积分得\sqrt{1-y^2}=x+c,即\sqrt{1-x'^2}=x+c$
#
# $\therefore x'=\pm \sqrt{1-(x+c)^2},二次积分得$
#
# $1.当x'=\sqrt{1-(x+c)^2}时,x=\sin (t+c_1)+c_2;$
#
# $2.当x'=-\sqrt{1-(x+c)^2}时,x=\cos (t+c_1)+c_2;$
#
# $当y=\pm 1时，x'=\pm 1,\therefore x=\pm t+c$
#
# $\therefore 原方程的解为x=\sin (t+c_1)+c_2或x=\cos (t+c_1)+c_2或x=\pm t+c,其中c_1,c_2，c为任意常数$

# %% [markdown]
# $(6)解：当x' \pm 0时，方程两边同时除以x'，得\frac{x"}{x'}-\frac{1}{t}+x'=0$
#
# $即d(\ln |x'|- \ln |t|+x)=0,积分得\ln |\frac{x'}{t}|+x=c_1,得x'=t(e^{-x+c}),二次积分得e^x=e^{c_1}(\frac{t^2}{2})+c_2$
#
# $\therefore e^x=c'_1(t^2+c'_2),当x=0时，即得x=c,$
#
# $\therefore方程的解为e^x=c'_1(t^2+c'_2),或x=c,（c,c'_1,c'_2为任意常数）$

# %% [markdown]
# $P184\quad2.$

# %% [markdown]
# $P201\quad2.$

# %% [markdown]
# $(3)解:令w_1=x,w_2=x',w_3=y,w_4=y',则原初值问题可化为$
#
# $$
# \begin{cases}
# w_1=x=w_2\\
# w_2'=x"=-5w_4+7w_1-6w_3+e^t\\
# w_3=y=w_4\\
# w_4'=y"=2w_3-13w_4+15w_1+ \cos t\\
# \end{cases}
# 且
# \begin{cases}
# w_1(0)=x(0)=1\\
# w_2(0)=x'(0)=0\\
# w_3(0)=y(0)=0\\
# w_4(0)=y'(0)=1\\
# \end{cases}
# w=
# \begin{bmatrix}
# w_1\\
# w_2\\
# w_3\\
# w_4\\
# \end{bmatrix}
# $$
#
# $$
# 即
# w'=
# \begin{bmatrix}
# 0&1&0&0\\
# 7&0&-6&-5\\
# 0&0&0&1\\
# 15&0&2&-13\\
# \end{bmatrix}
# w+
# \begin{bmatrix}
# 0\\
# e^t\\
# 0\\
# \cos t\\
# \end{bmatrix}
# w(0)=
# \begin{bmatrix}
# 1\\
# 0\\
# 0\\
# 1\\
# \end{bmatrix}
# $$

# %% [markdown]
# $3.解:令方程的解为\varphi(t)$
#
# $$
# 取\varphi_0(t)=x(0)=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# $$
#
# $\therefore第一次近似解为$
# $$
# \varphi_1(t)=\varphi_0(t)+\int\limits_0^{t} A(s)\varphi_0(s) d s=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 0&1\\
# -1&0\\
# \end{bmatrix}
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 1\\
# 0\\
# \end{bmatrix}
# d s
# =\begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\begin{bmatrix}
# t\\
# 0\\
# \end{bmatrix}
# =\begin{bmatrix}
# t\\
# 1\\
# \end{bmatrix}
# $$
#
# $\therefore第二次近似解为$
# $$
# \varphi_2(t)=\varphi_0(t)+\int\limits_0^{t} A(s)\varphi_1(s) d s=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 0&1\\
# -1&0\\
# \end{bmatrix}
# \begin{bmatrix}
# s\\
# 1\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 1\\
# -s\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \begin{bmatrix}
# t\\
# -\frac{t^2}{2}\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# t\\
# 1-\frac{t^2}{2}\\
# \end{bmatrix}
# $$
#
# $\therefore第三次近似解为$
# $$
# \varphi_1(t)=\varphi_0(t)+\int\limits_0^{t} A(s)\varphi_2(s) d s=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \int\limits_0^{t}
# \begin{bmatrix}
# 0&1\\
# -1&0\\
# \end{bmatrix}
# \begin{bmatrix}
# s\\
# 1-\frac{s^2}{2}\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \int\limits_0^{t}
# \begin{bmatrix}
# 1-\frac{s^2}{2}\\
# -s\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \begin{bmatrix}
# t-\frac{t^3}{3!}\\
# -\frac{t^2}{2!}\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# t-\frac{t^3}{3!}\\
# 1-\frac{t^2}{2!}\\
# \end{bmatrix}
# $$
