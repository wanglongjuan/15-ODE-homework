# %% [markdown]
# *一.求解下列方程*

# %% [markdown]
# $(1).xx''-(x')^2+(x')^3=0$

# %% [markdown]
# 解：方程不含t,令$x'=y$，直接计算得$x''=y\frac{dy}{dx}$,则方程变为
#
# $xy\frac{dy}{dx}-y^2+y^3=0$得$y=0$即$x=c$或$x\frac{dy}{dx}=y(1-y),\frac{dx}{x}=(\frac{1}{y}-\frac{1}{y-1})dy$,积分得
#
# $y=\frac{\mathrm cx}{\mathrm cx-1}$,有$x'=\frac{\mathrm cx}{\mathrm cx-1}$,积分得$x-\frac{1}{\mathrm c}\ln{x}=t+c_2$,即得方程有解
#
# $x+c_1\ln{x}=t+c_2,及x=c$

# %% [markdown]
# $(2).x''+\sqrt{1-(x')^2}=0$

# %% [markdown]
# 解：方程不含t,x,令$x'=y$，则方程变为
#
# $y'+\sqrt{1-y^2}=0$
#
# 可分离变量解之:
#
# $\frac{dy}{\sqrt{1-y^2}}=-dt,arcsin y=c_1-t,x'=y=sin(c_1-t)$
#
# $x=cos(t-c_1)+c_2$
#
# 方程的解为$x=cos(t-c_1)+c_2,又y^2=1,y=\pm 1时x'=\pm 1,x=\pm t+c$也是解。

# %% [markdown]
# $(3).x''-\frac{1}{t}x'+(x')^2=0$（提示：方程两端除以$x'$）

# %% [markdown]
# *二.用幂级数解法求解下列方程*

# %% [markdown]
# $(1).(1-t)x''+x=0$

# %% [markdown]
# 设级数$x=a_0+a_1t+a_2t^2+…+a_nt^n+…$为方程的解，
#
# $x''=2a_2+3\cdot2a_3t…+n(n-1)a_nt^{n-2}+…$
#
# 将$x'',x$代入原方程，并合并同类项可得：
# $a_0+2a_2=0,3\cdot2a_3-2a_2+a_1=0$
#
# $k(k-1)a_k-(k-1)(k-2)a_{k-1}+a_{k-2}=0,k>3$
#
# 考虑方程的通解，可设$x(0)=c_1,x'(0)=c_2,有a_0=c_1,a_1=c_2,a_2=-\frac{1}{2}c_1,a_3=-\frac{1}{3!}c_1-\frac{1}{3!}c_2,$
#
# $a_k=\frac{k-2}{k}a_{k-1}-\frac{1}{k(k-1}a_{k-2}(k>3)'$
#
# 于是可逐次递推求得幂级数的解：
#
# $x=c_1(1-\frac{1}{2}t^2-\frac{1}{3!}t^3-\frac{1}{4!}t^4-\frac{2}{5!}t^5-…）+$
#
# $c_2(t-\frac{1}{3!}t^3-\frac{2}{4!}t^4-\frac{5}{5!}t^5-\frac{18}{6!}t^6-…)$

# %% [markdown]
# *三.将下面的初值问题化为与之等价的一阶方程组的初值问题*

# %% [markdown]
# $(1).\begin{cases}
# x''+5y'-7x+6y=e^t\\
# y''-2y+13y'-15x=cost'
# \end{cases}$
#
# $x(0)=1,x'(0)=0,y(0)=0,y'(0)=1.$
#
# (提示：令$w_1=x,w_2=x',w_3=y,w_4=y'$)

# %% [markdown]
# $(3)解:令w_1=x,w_2=x',w_3=y,w_4=y',则原初值问题可化为$
#
# $$
# \begin{cases}
# w_1=x=w_2\\
# w_2'=x"=-5w_4+7w_1-6w_3+e^t\\
# w_3=y=w_4\\
# w_4'=y"=2w_3-13w_4+15w_1+ \cos t\\
# \end{cases}
# 且
# \begin{cases}
# w_1(0)=x(0)=1\\
# w_2(0)=x'(0)=0\\
# w_3(0)=y(0)=0\\
# w_4(0)=y'(0)=1\\
# \end{cases}
# w=
# \begin{bmatrix}
# w_1\\
# w_2\\
# w_3\\
# w_4\\
# \end{bmatrix}
# $$
#
# $$
# 即
# w'=
# \begin{bmatrix}
# 0&1&0&0\\
# 7&0&-6&-5\\
# 0&0&0&1\\
# 15&0&2&-13\\
# \end{bmatrix}
# w+
# \begin{bmatrix}
# 0\\
# e^t\\
# 0\\
# \cos t\\
# \end{bmatrix}
# w(0)=
# \begin{bmatrix}
# 1\\
# 0\\
# 0\\
# 1\\
# \end{bmatrix}
# $$

# %% [markdown]
# *四.试用逐步逼近法求方程组*
# $$x'=\begin{bmatrix}
#  0&1\\
# -1&0
# \end{bmatrix}x,$$
# 满足初值条件
# $$x(0)=\begin{bmatrix}
#  0\\
# 1
# \end{bmatrix}$$
# 的第三次近似解。

# %% [markdown]
# $3.解:令方程的解为\varphi(t)$
#
# $$
# 取\varphi_0(t)=x(0)=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# $$
#
# $\therefore第一次近似解为$
# $$
# \varphi_1(t)=\varphi_0(t)+\int\limits_0^{t} A(s)\varphi_0(s) d s=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 0&1\\
# -1&0\\
# \end{bmatrix}
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 1\\
# 0\\
# \end{bmatrix}
# d s
# =\begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\begin{bmatrix}
# t\\
# 0\\
# \end{bmatrix}
# =\begin{bmatrix}
# t\\
# 1\\
# \end{bmatrix}
# $$
#
# $\therefore第二次近似解为$
# $$
# \varphi_2(t)=\varphi_0(t)+\int\limits_0^{t} A(s)\varphi_1(s) d s=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 0&1\\
# -1&0\\
# \end{bmatrix}
# \begin{bmatrix}
# s\\
# 1\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +\int\limits_0^{t}
# \begin{bmatrix}
# 1\\
# -s\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \begin{bmatrix}
# t\\
# -\frac{t^2}{2}\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# t\\
# 1-\frac{t^2}{2}\\
# \end{bmatrix}
# $$
#
# $\therefore第三次近似解为$
# $$
# \varphi_1(t)=\varphi_0(t)+\int\limits_0^{t} A(s)\varphi_2(s) d s=
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \int\limits_0^{t}
# \begin{bmatrix}
# 0&1\\
# -1&0\\
# \end{bmatrix}
# \begin{bmatrix}
# s\\
# 1-\frac{s^2}{2}\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \int\limits_0^{t}
# \begin{bmatrix}
# 1-\frac{s^2}{2}\\
# -s\\
# \end{bmatrix}
# d s
# =
# \begin{bmatrix}
# 0\\
# 1\\
# \end{bmatrix}
# +
# \begin{bmatrix}
# t-\frac{t^3}{3!}\\
# -\frac{t^2}{2!}\\
# \end{bmatrix}
# =
# \begin{bmatrix}
# t-\frac{t^3}{3!}\\
# 1-\frac{t^2}{2!}\\
# \end{bmatrix}
# $$
